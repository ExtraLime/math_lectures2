# %% [markdown]
# ## Scraping Closed Captions from YouTube
#     -In this notebook we will set up a mechanism to download subtitles from youtube videos.
#     -There are a few different approaches.
#     -For my project we start with a list of playlists that were chosen by hand
#     -However, a function to return search results and filter them is also present

# %%
import pandas as pd
import os
import webvtt
import google.oauth2.credentials
import time

import google_auth_oauthlib.flow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google_auth_oauthlib.flow import InstalledAppFlow

# %%
#use google's resource builder code from API documentation

# The CLIENT_SECRETS_FILE variable specifies the name of a file that contains
# the OAuth 2.0 information for this application, including its client_id and
# client_secret.
CLIENT_SECRETS_FILE = "client_secret.json"

# This OAuth 2.0 access scope allows for full read/write access to the
# authenticated user's account and requires requests to use an SSL connection.
SCOPES = ['https://www.googleapis.com/auth/youtube.force-ssl']
API_SERVICE_NAME = 'youtube'
API_VERSION = 'v3'


def get_authenticated_service():
    flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
    credentials = flow.run_console()
    return build(API_SERVICE_NAME, API_VERSION, credentials = credentials)

def print_response(response):
    print(response)

# Build a resource based on a list of properties given as key-value pairs.
# Leave properties with empty values out of the inserted resource.
def build_resource(properties):
    resource = {}
    for p in properties:
    # Given a key like "snippet.title", split into "snippet" and "title", where
    # "snippet" will be an object and "title" will be a property in that object.
        prop_array = p.split('.')
        ref = resource
    for pa in range(0, len(prop_array)):
        is_array = False
        key = prop_array[pa]

        # For properties that have array values, convert a name like
        # "snippet.tags[]" to snippet.tags, and set a flag to handle
        # the value as an array.
        if key[-2:] == '[]':
            key = key[0:len(key)-2:]
            is_array = True

        if pa == (len(prop_array) - 1):
             # Leave properties without values out of inserted resource.
            if properties[p]:
                if is_array:
                    ref[key] = properties[p].split(',')
                else:
                    ref[key] = properties[p]
        elif key not in ref:
            # For example, the property is "snippet.title", but the resource does
            # not yet have a "snippet" object. Create the snippet object here.
            # Setting "ref = ref[key]" means that in the next time through the
            # "for pa in range ..." loop, we will be setting a property in the
            # resource's "snippet" object.
            ref[key] = {}
            ref = ref[key]
        else:
            # For example, the property is "snippet.description", and the resource
            # already has a "snippet" object.
            ref = ref[key]
    return resource

# Remove keyword arguments that are not set
def remove_empty_kwargs(**kwargs):
    good_kwargs = {}
    if kwargs is not None:
        for key, value in kwargs.items():
            if value:
                good_kwargs[key] = value
    return good_kwargs

if __name__ == '__main__':
    # When running locally, disable OAuthlib's HTTPs verification. When
    # running in production *do not* leave this option enabled.
    os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
    client = get_authenticated_service()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=111385062335-jq2vrqf7hvtp6mfh2o5bprq11sabsq1r.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.force-ssl&state=DfoE7FZXxyd0CPQkMlzm44eN4kJwXp&prompt=consent&access_type=offline
# Enter the authorization code: 4/4wBDp-DRrBAIbklO7zQqLgGxUbx5Y44eemC4b_KIcjgmKjKWhW9drwA

# %% [markdown]
# ## Function to search videos by search term
#     - Given a search term and an integer n, this function will return the n first results for the term
#     - Videos are limited to those that have CCs and are longer than 20 minutes (these paramenters can be changed)
#     - Returns a DF with the video title,videoID, and channelID

# %%
def youtube_keyword(client, **kwargs):    
    # See full sample for function
    kwargs = remove_empty_kwargs(**kwargs)
    response = client.search().list(
        **kwargs
        ).execute()    
    return response

def youtube_search (criteria,n_terms):   
    #create lists and empty dataframe
    titles = []
    videoIds = []
    channelIds = []
    resp_df = pd.DataFrame()
    
    while len(titles) < n_terms:
        token = None
        response = youtube_keyword(client,
                        part='id,snippet',
                        maxResults=50,
                        q=criteria,#whatever you search for above
                        videoCaption='closedCaption',#we only want videos with CCs
                        type='video', #because we specify duration
                        videoDuration='long',#videos longer than 20 minutes
                        pageToken=token) #this will update for the next 50 results
                                         
        for item in response['items']:
        
            titles.append(item['snippet']['title'])
            channelIds.append(item['snippet']['channelTitle'])
            videoIds.append(item['id']['videoId'])
        
        token = response['nextPageToken']
    resp_df['titles'] = titles
    resp_df['channelIds'] = channelIds
    resp_df['videoIds'] = videoIds
    
    return resp_df

#Sample usage

'''Linear_Algebra_Videos = youtube_search('[linear+algebra]',1000)'''
# Out:
# "Linear_Algebra_Videos = youtube_search('[linear+algebra]',1000)"

# %% [markdown]
# ## Function to get a list of videoIDs for a given playlist
#     -This function takes a playlistID and returns a list of videosIDs for that playlistID

# %%
def playlist_items_list_by_playlist_id(client, **kwargs):
    # See full sample for function
    kwargs = remove_empty_kwargs(**kwargs)

    response = client.playlistItems().list(
    **kwargs
    ).execute()

    return response


def get_vid_ids (play_lists):
    #generate data from call
    titles = []
    descriptions = []
    channelids = []
    vidids = []
    playlist_ids = []
    video_df = pd.DataFrame()
    for play_list in play_lists:
        #request playlist items
        pl_data = playlist_items_list_by_playlist_id(client,
                            part='snippet,contentDetails',
                            maxResults=50,
                            playlistId=play_list)
        
        #extract information about each video in the playlist
        
        for item in pl_data['items']:
                titles.append(item['snippet']['title'])
                descriptions.append(item['snippet']['description'])
                channelids.append(item['snippet']['channelTitle'])
                vidids.append(item['snippet']['resourceId']['videoId'])
                playlist_ids.append(item['snippet']['playlistId'])
                
    video_df['title'] = titles
    video_df['description'] = descriptions
    video_df['channelid'] = channelids
    video_df['videoids'] = vidids
    video_df['playlist_id'] = playlist_ids
            
                
    return video_df

# %% [markdown]
# ## Importing a list of playlists

# %%
#import csv of target play lists
pl_df = pd.read_csv('playlists_math.csv')
#coorect a playlist
pl_df.iloc[16].PlaylistID = 'PLUl4u3cNGP61hsJNdULdudlRL493b-XZf'

# %%
pl_df.PlaylistID

# %%
#call our function to get the videoIDs of the playlists
t1 = time.time()
video_df = get_vid_ids(pl_df.PlaylistID)
print("Num Videos listed in {} minutes".format((time.time()-t1)/60))
# Out:
# Num Videos listed in 0.25398961702982586 minutes

# %%
print('Number of VideoIds downloaded: {}'.format(len(video_df.videoids)))
# Out:
# Number of VideoIds downloaded: 1285

# %% [markdown]
# ## Function to scrape Captions
#     -Given a list of videoIds, this function will download the CCs if available.
#     -As this function does not utilize the API, it is not subject to a quota(be nice)
#     -Also, its slow so be patient

# %%
#This is the function that will actually download the CCs, it takes a while as it writes a .vtt file to disk
def get_all_ccs(vids):
    base_url = 'https://www.youtube.com/watch?v='
    lang="en"
    for vid in vids:
        url = base_url + vid
        cmd = ["youtube-dl","--skip-download","--write-sub",
               "--sub-lang",lang,url]
        os.system(" ".join(cmd))

# %%
t1 = time.time()

get_all_ccs(video_df.videoids)

print("Captions downloaded in {} minutes".format((time.time()-t1)/60))
# Out:
# Captions downloaded in 0.9936846733093262 minutes

# %%
#Enumerate .vtt files in cwd
filenames_vtt = filenames_vtt = [os.fsdecode(file) for file in os.listdir(os.getcwd())\
                                 if os.fsdecode(file).endswith(".vtt")]
print('Captions Downloaded {}'.format(len(filenames_vtt)))
# Out:
# Captions Downloaded 195

# %%
#look at how they're saved
filenames_vtt[:2]
# Out:
# ['Determining whether a transformation is onto _ Linear Algebra _ Khan Academy-eR8vEdJTvd0.en.vtt',
#  'More on linear independence _ Vectors and spaces _ Linear Algebra _ Khan Academy-Alhcv5d_XOs.en.vtt']

# %% [markdown]
# ## Fuction to convert .vtt files to csv files
#     -Given a list of file names, this funtion will convert the .vtt in the cwd to
#     a csv file with the test, start time and stop time for each line.
#     -it also removes the downloaded .vtt files

# %%
def convert_vtt(filenames):    
    #create an assets folder if one does not yet exist
    if os.path.isdir('{}/assets2'.format(os.getcwd())) == False:
        os.makedirs('assets2')
    #extract the text and times from the vtt file
    for file in filenames:
        captions = webvtt.read(file)
        text_time = pd.DataFrame()
        text_time['text'] = [caption.text for caption in captions]
        text_time['start'] = [caption.start for caption in captions]
        text_time['stop'] = [caption.end for caption in captions]
        text_time.to_csv('assets2/{}.csv'.format(file[:-4]),index=False) #-4 to remove '.vtt'
        #remove files from local drive
        os.remove(file)

# %%
#convert the vtt and creat csvs in assets folder
convert_vtt(filenames_vtt)

# %% [markdown]
# ## General Clean up
#     -Here clean up the csv file names and get the text into a dataframe

# %%
#Get a list of the CSV files 
csv_files = [os.fsdecode(file) for file in os.listdir(os.getcwd()+'/math2clean/assets') \
                    if os.fsdecode(file).endswith('.csv')]

# %%
len(csv_files)
# Out:
# 868

# %%
csv_files
# Out:
# ['VisualizingacolumnspaceasaplaneinR3_Vectorsandspaces_LinearAlgebra_KhanAcademy-EGNlXtjYABw.en.csv',
#  'Modelingpopulationwithsimpledifferentialequation_KhanAcademy-IYFkXWlgC_w.en.csv',
#  'FunctionsasArguments-QaOHeMnpnmU.en.csv',
#  'Introductiontoprojections_Matrixtransformations_LinearAlgebra_KhanAcademy-27vT-NWuw0M.en.csv',
#  '11.DynamicProgramming-All-PairsShortestPaths-NzgFUwOaoIw.en.csv',
#  'Lec16_MIT18.02MultivariableCalculus,Fall2007-YP_B0AapU0c.en.csv',
#  '6.MaximumLikelihoodEstimation(cont.)andtheMethodofMoments-JTbZP0yt9qc.en.csv',
#  'Lec19_MIT18.03DifferentialEquations,Spring2006-sZ2qulI6GEk.en.csv',
#  'L05.2DefinitionofRandomVariables-vfqPpai_9jI.en.csv',
#  'Lec6_MIT6.042JMathematicsforComputerScience,Fall2010-h9wxtqoa1jY.en.csv',
#  'Mean&VarianceoftheExponential-GJ2klfD0Q3g.en.csv',
#  'ComputingtheFourFundamentalSubspaces-D8u1LV9CnCk.en.csv',
#  '11.Learning-IdentificationTrees,Disorder-SXBG3RGr_Rc.en.csv',
#  'Lec26_MIT18.02MultivariableCalculus,Fall2007-RMBGQtwkoyU.en.csv',
#  'Lecture5-ConditioningContinued,LawofTotalProbability_Statistics110-JzDvVgNDxo8.en.csv',
#  'Lec24_MIT6.042JMathematicsforComputerScience,Fall2010-q4mwO2qS2z4.en.csv',
#  'Creatingaslopefield_Firstorderdifferentialequations_KhanAcademy-8Amgakx5aII.en.csv',
#  'Determinantasscalingfactor_Matrixtransformations_LinearAlgebra_KhanAcademy-g3MqSdO5Ubc.en.csv',
#  '17.Bellman-Ford-ozsuci5pIso.en.csv',
#  'Lec27_MIT18.086MathematicalMethodsforEngineersII-iVUsEwSg-lw.en.csv',
#  '11.Renewals-StrongLawandRewards-QWHtRR1jMEQ.en.csv',
#  'Lec17_MIT6.042JMathematicsforComputerScience,Fall2010-09yIb3VHhMI.en.csv',
#  'Compositionsoflineartransformations1_Matrixtransformations_LinearAlgebra_KhanAcademy-f_DTiXZpb8M.en.csv',
#  'L02.6TheMultiplicationRule-ugzs7dgQ-JE.en.csv',
#  'Lec5_MIT18.01SingleVariableCalculus,Fall2007-5q_3FDOkVRQ.en.csv',
#  'S01.9ProofThataSetofRealNumbersisUncountable-YIZd23zGV3M.en.csv',
#  'Particularsolutiongiveninitialconditionsforpopulation_KhanAcademy-6jqx5uEBs5U.en.csv',
#  'Logisticdifferentialequationintuition_Firstorderdifferentialequations_KhanAcademy-oiDvNs15tkE.en.csv',
#  'Week8-9qvt6MwBKZQ.en.csv',
#  '9.MultipleContinuousRandomVariables-CadZXGNauY0.en.csv',
#  'L02.1LectureOverview-B5y6fy5iUtg.en.csv',
#  'Lec19_MIT18.01SingleVariableCalculus,Fall2007-1RLctDS2hUQ.en.csv',
#  '21.DynamicConnectivityLowerBound-Yarwp7TNTL4.en.csv',
#  'ExploringthesolutionsetofAx=b_Matrixtransformations_LinearAlgebra_KhanAcademy-1PsNIzUJPkc.en.csv',
#  'Lecture33-MarkovChainsContinuedFurther_Statistics110-Q-pCzTpwPBU.en.csv',
#  '17.BayesianStatistics-bFZ-0FH5hfs.en.csv',
#  '12.FusionTrees-xSGorVW8j6Q.en.csv',
#  '23.Cache-ObliviousAlgorithms-Medians&Matrices-CSqbjfCCLrU.en.csv',
#  'L01.10Interpretations&UsesofProbabilities-uGGTX2ypzKI.en.csv',
#  'Lec33_MIT18.03DifferentialEquations,Spring2006-kRR9EVzr4lc.en.csv',
#  '16.Strings-NinWEPPrkDQ.en.csv',
#  'L04.1LectureOverview-poeHeiiiLKI.en.csv',
#  'Lecture19-Joint,Conditional,andMarginalDistributions_Statistics110-J70dP_AECzQ.en.csv',
#  'L03.4IndependenceofEventComplements-JZkT3NU2mPM.en.csv',
#  'Lecture17-IssuesinNLPandPossibleArchitecturesforNLP-B4v545V3Dq0.en.csv',
#  '10.UnderstandingProgramEfficiency,Part1-o9nW0uBqvEo.en.csv',
#  'Bindings-EFCdr_43qmU.en.csv',
#  'Vectortransformations_Matrixtransformations_LinearAlgebra_KhanAcademy-gAbadNuQEjI.en.csv',
#  '19.PrincipalComponentAnalysis-WW3ZJHPwvyg.en.csv',
#  'Lec18_MIT18.01SingleVariableCalculus,Fall2007-hjZhPczMkL4.en.csv',
#  'R15.ShortestPaths-mQSp6VmfakA.en.csv',
#  'Lec9_MIT18.086MathematicalMethodsforEngineersII-sleOqiMUTXE.en.csv',
#  'Lec16_MIT18.086MathematicalMethodsforEngineersII-XPo4dHK48Nw.en.csv',
#  'Lec16_MIT18.06LinearAlgebra,Spring2005-osh80YCg_GM.en.csv',
#  'Separabledifferentialequationsintroduction_Firstorderdifferentialequations_KhanAcademy-DL-ozRGDlkY.en.csv',
#  'Formulafor2x2inverse_Matrixtransformations_LinearAlgebra_KhanAcademy-eEUK_ThrHuQ.en.csv',
#  '25.IdealQuantumGasesPart5-6rn4q9mv4jQ.en.csv',
#  'Derivingamethodfordetermininginverses_Matrixtransformations_LinearAlgebra_KhanAcademy-6DpzCKJBsz0.en.csv',
#  'Lecture22-TransformationsandConvolutions_Statistics110-yXwPUAIvFyg.en.csv',
#  'AmbulanceTravelTime-gpMLYEMIw24.en.csv',
#  'L{sin(at)})-transformofsin(at)_Laplacetransform_DifferentialEquations_KhanAcademy-gMcs6RF_LrQ.en.csv',
#  'Lec12_MIT18.06LinearAlgebra,Spring2005-6-wh6yvk6uc.en.csv',
#  '7.DiscreteRandomVariablesIII-EObHWIEKGjA.en.csv',
#  'R11.PrinciplesofAlgorithmDesign-a_otxyu0mSQ.en.csv',
#  'Lec4_MIT18.086MathematicalMethodsforEngineersII-HHwDX-3IPT0.en.csv',
#  '10.RenewalsandtheStrongLawofLargeNumbers-uHMVJJHsym4.en.csv',
#  'Lec3_MIT18.03DifferentialEquations,Spring2006-tVzaX9u6YAE.en.csv',
#  '7.ParametricHypothesisTesting-phbw9r1iUDI.en.csv',
#  'Mega-R7.NearMisses,ArchLearning-J-ocRQCjcwE.en.csv',
#  'Advanced6.PlanningwithTemporalLogic-Tmhe33f9mWA.en.csv',
#  'L01.3SampleSpaceExamples-__T3eJtjoic.en.csv',
#  'Distancebetweenplanes_Vectorsandspaces_LinearAlgebra_KhanAcademy-v8plb6V8BQo.en.csv',
#  'Rowspaceandleftnullspace_Matrixtransformations_LinearAlgebra_KhanAcademy-qBfc57x_RSg.en.csv',
#  'R11.Cryptography-MorePrimitives-ZLOhV4XQ_tI.en.csv',
#  '2.MoreReview;TheBernoulliProcess-d4xfax4_Iww.en.csv',
#  'Oldseparabledifferentialequationsintroduction_KhanAcademy-C5-lz0hcqsE.en.csv',
#  'Lec29_MIT18.01SingleVariableCalculus,Fall2007-HgEqXhsIq_g.en.csv',
#  '14.SortinginLinearTime-pOKy3RZbSws.en.csv',
#  'Lec24_MIT18.01SingleVariableCalculus,Fall2007-jBkXbAgMj6s.en.csv',
#  'Provingvectordotproductproperties_Vectorsandspaces_LinearAlgebra_KhanAcademy-rVQ3G9epCjw.en.csv',
#  '23.GeneralizedLinearModels(cont.)-OYcdw5vOgIc.en.csv',
#  'Findheightofabinarytree-_pnqMz5nrRs.en.csv',
#  'Lec5_MIT6.042JMathematicsforComputerScience,Fall2010-XX7ePR21Ook.en.csv',
#  'Lecture13-ConvolutionalNeuralNetworks-Lg6MZw_OOLI.en.csv',
#  'Dotandcrossproductcomparison_intuition_Vectorsandspaces_LinearAlgebra_KhanAcademy-tdwFdzVqito.en.csv',
#  'Exactequationsexample1_Firstorderdifferentialequations_KhanAcademy-Pb04ntcDJcQ.en.csv',
#  'ProjectionintoSubspaces-t-n4a18AW08.en.csv',
#  '10.DynamicProgramming-AdvancedDP-Tw1k46ywN6E.en.csv',
#  'Lec26_MIT18.03DifferentialEquations,Spring2006-hEtWqTPPXuc.en.csv',
#  '11.UnderstandingProgramEfficiency,Part2-7lQXYl_L28w.en.csv',
#  'LinkedListinC_C++-Insertanodeatnthposition-IbvsNF22Ud0.en.csv',
#  'Lec19_MIT18.06LinearAlgebra,Spring2005-23LLB9mNJvc.en.csv',
#  'DataStructures-ArraysvsLinkedLists-lC-yYCOnN8Q.en.csv',
#  '13.Learning-GeneticAlgorithms-kHyNqSnzP8Y.en.csv',
#  'L01.5SimplePropertiesofProbabilities-WTyLg_I1oFY.en.csv',
#  'Lec30_MIT18.01SingleVariableCalculus,Fall2007-aeXp1zC6Hls.en.csv',
#  'Lecture18-Epilogue-ihLwJPHkMRY.en.csv',
#  'Lec23_MIT18.02MultivariableCalculus,Fall2007-_CdoRiNSrqI.en.csv',
#  'Theconvolutionandthelaplacetransform_Laplacetransform_KhanAcademy-TJgBEI3drUc.en.csv',
#  '1.IntroductiontoStatistics-VPZD_aij8H0.en.csv',
#  '14.IncrementalImprovement-Matching-8C_T4iTzPCU.en.csv',
#  '21.DPIII-Parenthesization,EditDistance,Knapsack-ocZMDMZwhCY.en.csv',
#  'R6.AVLTrees-IWzYoXKaRIc.en.csv',
#  'R7.NetworkFlowandMatching-0CdxkgAjsDA.en.csv',
#  'Lec14_MIT6.042JMathematicsforComputerScience,Fall2010-Kqf0uO0oV6s.en.csv',
#  '14.Review-pY9ol9So2Yw.en.csv',
#  'R2.PythonCostModel,DocumentDistance-QFcyt8fgQMU.en.csv',
#  '11.DerivedDistributions(ctd.);Covariance-l4NoMKEHQwM.en.csv',
#  "ApplyingNewton'sLawofCoolingtowarmoatmeal_Firstorderdifferentialequations_KhanAcademy-jH5qflAe3C8.en.csv",
#  'InverseMatrices-zWxhmBCdvFs.en.csv',
#  'Lec33_MIT18.06LinearAlgebra,Spring2005-Go2aLo7ZOlU.en.csv',
#  'Lec26_MIT18.086MathematicalMethodsforEngineersII-xzUOJ-uQ8F0.en.csv',
#  '2.BranchingandIteration-0jljZRnHwOI.en.csv',
#  'Lec29_MIT18.02MultivariableCalculus,Fall2007-wu8kXZSAp20.en.csv',
#  'L04.3DieRollExample-KrjZyCRi29o.en.csv',
#  'Unitvectors_Matrixtransformations_LinearAlgebra_KhanAcademy-lQn7fksaDq0.en.csv',
#  'S01.8CountableandUncountableSets-MqocbJ-FPo0.en.csv',
#  'Datastructures-IntroductiontoDoublyLinkedList-JdQeNxWCguQ.en.csv',
#  'Lec33_MIT18.01SingleVariableCalculus,Fall2007-BGE3wb7H2PA.en.csv',
#  'Lec5_MIT18.06LinearAlgebra,Spring2005-JibVXBElKL0.en.csv',
#  'Exactequationsexample3_Firstorderdifferentialequations_KhanAcademy-eu_GFuU7tLI.en.csv',
#  'Lec34_MIT18.02MultivariableCalculus,Fall2007-ZwpwmGP5ITM.en.csv',
#  '4.Search-Depth-First,HillClimbing,Beam-j1H3jAAGlEA.en.csv',
#  '9.Augmentation-RangeTrees-xVka6z1hu-I.en.csv',
#  'GettersandSetters-C_pgH5QhIZ8.en.csv',
#  'Lec24b_MIT18.06LinearAlgebra,Spring2005-sFxA8eIS6tA.en.csv',
#  'Spanandlinearindependenceexample_Vectorsandspaces_LinearAlgebra_KhanAcademy-9kW6zFK5E5c.en.csv',
#  '5.PoissonCombiningandSplitting-ct0QGoi3n4Q.en.csv',
#  '13.Little,M_G_1,EnsembleAverages-pOhZUJ5BQXk.en.csv',
#  'Lec32_MIT18.06LinearAlgebra,Spring2005-HgC1l_6ySkc.en.csv',
#  '4.Poisson(thePerfectArrivalProcess)-qxaBDDib9_A.en.csv',
#  'Lec1_MIT18.02MultivariableCalculus,Fall2007-PxCxlsl_YwY.en.csv',
#  'Lec10_MIT18.02MultivariableCalculus,Fall2007-3_goGnJm5sA.en.csv',
#  'Addingvectors_Vectorsandspaces_LinearAlgebra_KhanAcademy-8QihetGj3pg.en.csv',
#  '13.IncrementalImprovement-MaxFlow,MinCut-VYZGlgzr_As.en.csv',
#  'Lec13_MIT18.03DifferentialEquations,Spring2006-9KbpbBMThTE.en.csv',
#  '14.ClassicalStatisticalMechanicsPart3-tCxonq5r-O8.en.csv',
#  'Lec4_MIT18.01SingleVariableCalculus,Fall2007-4sTKcvYMNxk.en.csv',
#  'Vectorintroforlinearalgebra_Vectorsandspaces_LinearAlgebra_KhanAcademy-br7tS1t2SFE.en.csv',
#  'Undeterminedcoefficients4_Secondorderdifferentialequations_KhanAcademy-vAepSNDLZRM.en.csv',
#  'Mega-R2.BasicSearch,OptimalSearch-Tl_p5pgBsyM.en.csv',
#  '4.HeapsandHeapSort-B7hVxCmfPtM.en.csv',
#  "S01.10Bonferroni'sInequality-0xuRh3dz_Nc.en.csv",
#  '4.GeometricStructuresII-FzS0n_Z8lrk.en.csv',
#  'Transposeofamatrix_Matrixtransformations_LinearAlgebra_KhanAcademy-2t0003_sxtU.en.csv',
#  '16.Complexity-P,NP,NP-completeness,Reductions-eHZifpgyH_4.en.csv',
#  'Lec21_MIT18.03DifferentialEquations,Spring2006-3ejfkMHr_DE.en.csv',
#  'Lec24_MIT18.06LinearAlgebra,Spring2005-8MF3pz-oYHo.en.csv',
#  'Matrixvectorproductsaslineartransformations_LinearAlgebra_KhanAcademy-ondmopWLiEg.en.csv',
#  'Lec7_MIT18.06LinearAlgebra,Spring2005-VqP2tREMvt0.en.csv',
#  'Lecture02-IsLearningFeasible-MEG35RDD7RA.en.csv',
#  '19.SynchronousDistributedAlgorithms-Symmetry-Breaking.Shortest-PathsSpanningTrees-mUBmcbbJNf4.en.csv',
#  '2.ModelsofComputation,DocumentDistance-Zc54gFhdpLA.en.csv',
#  'Integratingfactors2_Firstorderdifferentialequations_KhanAcademy-0NyeDUhKwBE.en.csv',
#  'Laplace_stepfunctiondifferentialequation_Laplacetransform_KhanAcademy-R0JY8oWsuOY.en.csv',
#  'ListOperations-SrkqbLOQcEo.en.csv',
#  'TheProbabilityoftheDifferenceofTwoEvents-o4Ccc1qJyAo.en.csv',
#  '2ndorderlinearhomogeneousdifferentialequations1_KhanAcademy-UFWAu8Ptth0.en.csv',
#  'Lec1_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-k6U-i4gXkLM.en.csv',
#  '5.Tuples,Lists,Aliasing,Mutability,andCloning-RvRKT-jXvko.en.csv',
#  'Printelementsofalinkedlistinforwardandreverseorderusingrecursion-K7J3nCeRC80.en.csv',
#  'PowersofaMatrix-5IGTFgPqlkw.en.csv',
#  'Firstorderhomogenousequations_Firstorderdifferentialequations_KhanAcademy-9Wfn-WWV1aY.en.csv',
#  'Lec15_MIT18.06LinearAlgebra,Spring2005-Y_Ac6KiQ1t0.en.csv',
#  'Lecture30-Chi-Square,Student-t,MultivariateNormal_Statistics110-MF-XSJOsGqw.en.csv',
#  'Transposesofsumsandinverses_Matrixtransformations_LinearAlgebra_KhanAcademy-Br_8t58mdeI.en.csv',
#  '15.TheLastRenewal-fY7NgCWCWoQ.en.csv',
#  'Particularsolutiontodifferentialequationexample_KhanAcademy-E444KhRcWSk.en.csv',
#  '22.IdealQuantumGasesPart2-hRHzPaDpgu0.en.csv',
#  'Lec17_MIT18.02MultivariableCalculus,Fall2007-60e4hdCi1D4.en.csv',
#  'Integratingfactors1_Firstorderdifferentialequations_KhanAcademy-j511hg7Hlbg.en.csv',
#  'Logisticfunctionapplication_Firstorderdifferentialequations_KhanAcademy--fIsaqN-aaQ.en.csv',
#  'S01.1Sets-47W1ApSRUqs.en.csv',
#  'Modelingpopulationasanexponentialfunction_Firstorderdifferentialequations_KhanAcademy-_JpS8k1a9yE.en.csv',
#  '6.AVLTrees,AVLSort-FNeL18KsWPc.en.csv',
#  '15.Learning-NearMisses,FelicityConditions-sh3EPjhhd40.en.csv',
#  'L03.7IndependenceofaCollectionofEvents-UbQcqFH33G0.en.csv',
#  'Lec16_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-Q8SoG1OIveU.en.csv',
#  '20.AsynchronousDistributedAlgorithms-Shortest-PathsSpanningTrees-kQ-UQAzcnzA.en.csv',
#  'Subclass-8s0d87sjy1A.en.csv',
#  'UniformProbabilitiesonaSquare-jxxrwZtpHH0.en.csv',
#  'Lec28_MIT18.06LinearAlgebra,Spring2005-z_zYQHmrh08.en.csv',
#  'Lec22_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-WGDbIKtjmSs.en.csv',
#  'Lec6_MIT18.01SingleVariableCalculus,Fall2007-9v25gg2qJYE.en.csv',
#  'ProbabilitythatThreePiecesFormaTriangle-xFS4xpYQ82w.en.csv',
#  '21.GeneralizedLinearModels-X-ix97pw0xY.en.csv',
#  '13.ClassicalStatisticalMechanicsPart2-Lt8FtWsq0q0.en.csv',
#  'Binarysearchtree-ImplementationinC_C++-COZK7NATh4k.en.csv',
#  'Week4,continued-lw1U7CvmjoU.en.csv',
#  'L05.1LectureOverview-ArfHGPHL8kU.en.csv',
#  'Lec35_MIT18.01SingleVariableCalculus,Fall2007-PNTnmH6jsRI.en.csv',
#  'Lec3_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-X6ilT3uUOBo.en.csv',
#  'Lec3_MIT18.06LinearAlgebra,Spring2005-FX4C-JpTFgY.en.csv',
#  'Datastructures-Arrayimplementationofstacks-sFVxsglODoo.en.csv',
#  'Advanced4.MonteCarloTreeSearch-xmImNoDc9Z4.en.csv',
#  'Lec1_MIT18.086MathematicalMethodsforEngineersII-gv-AB35V2k8.en.csv',
#  '2ndorderlinearhomogeneousdifferentialequations3_KhanAcademy-UyCwAFQt4v0.en.csv',
#  'Lec1_MIT18.01SingleVariableCalculus,Fall2007-7K1sB05pE0A.en.csv',
#  'RuleofSarrusofdeterminants_Matrixtransformations_LinearAlgebra_KhanAcademy-4xFIi0JF2AM.en.csv',
#  'Lec2_MIT18.06LinearAlgebra,Spring2005-QVKj3LADCnA.en.csv',
#  '19.DynamicGraphsI-XZLN6NxEQWo.en.csv',
#  'ReviewSession-MidtermReview-2DYxT4OMAmw.en.csv',
#  'Week10-FEvYzQQjulQ.en.csv',
#  'Lec11_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-DkPsD58nUIE.en.csv',
#  'Lec21_MIT18.01SingleVariableCalculus,Fall2007-_JXPe2J069c.en.csv',
#  '17.Learning-Boosting-UHBmv7qCey4.en.csv',
#  'Lecture27-ConditionalExpectationgivenanR.V._Statistics110-gjBvCiRt8QA.en.csv',
#  'Lec5_MIT18.086MathematicalMethodsforEngineersII-0aa6fUHTTeU.en.csv',
#  'R5.DynamicProgramming-krZI60lKPek.en.csv',
#  'Lec25_MIT6.042JMathematicsforComputerScience,Fall2010-56iFMY8QW2k.en.csv',
#  '8.Cache-ObliviousStructuresI-bY8f4DSkQ6M.en.csv',
#  '19.Architectures-GPS,SOAR,Subsumption,SocietyofMind-PimSbFGrwXM.en.csv',
#  'S01.6TheGeometricSeries-cCmWW7Hu43A.en.csv',
#  'Week9,continued-1-E78Cnq_Ko.en.csv',
#  'L03.1LectureOverview-QXKgTPR_8wk.en.csv',
#  '23.ComputationalComplexity-moPtwq_cVH8.en.csv',
#  "L03.10TheKing'sSibling-iPWyElxtk-8.en.csv",
#  'EliminationwithMatrices-GLFg2UBMAxc.en.csv',
#  'Solvingthelogisticdifferentialequationpart1_KhanAcademy-j_Taf2Tgggo.en.csv',
#  'ClassInstance-2__KumJsGXc.en.csv',
#  'Nullspace3-Relationtolinearindependence_Vectorsandspaces_LinearAlgebra_KhanAcademy-vFctYRhK2M0.en.csv',
#  'Lec2_MIT18.03DifferentialEquations,Spring2006-LbKKzMag5Rc.en.csv',
#  'Repeatedrootsofthecharacteristicequationspart2_KhanAcademy-YezsgIlcb68.en.csv',
#  '12.SearchingandSorting-6LOwPhPDwVc.en.csv',
#  '8.Randomization-Universal&PerfectHashing-z0lJ2k0sl1g.en.csv',
#  'Lec32_MIT18.03DifferentialEquations,Spring2006-z-meBrqcy_I.en.csv',
#  'Week1-DPJGJ5XOLFQ.en.csv',
#  'Multiplyingavectorbyascalar_Vectorsandspaces_LinearAlgebra_KhanAcademy-ZN7YaSbY3-w.en.csv',
#  'L02.4ConditionalProbabilitiesObeytheSameAxioms-L_pEeYLGaP0.en.csv',
#  'Lec6_MIT18.02MultivariableCalculus,Fall2007-0D4BbCa4gHo.en.csv',
#  'L03.2ACoinTossingExample-rZKUmNvCjis.en.csv',
#  'Introductiontotheinverseofafunction_Matrixtransformations_LinearAlgebra_KhanAcademy--eAzhBZgq28.en.csv',
#  'GeometryofLinearAlgebra-My5w4MXWBew.en.csv',
#  'Lecture10-NeuralNetworks-Ih5Mr93E-2c.en.csv',
#  'Lec8_MIT18.086MathematicalMethodsforEngineersII-FrrTXj13DNk.en.csv',
#  'Lec31_MIT18.03DifferentialEquations,Spring2006-UJG0f0BSX14.en.csv',
#  'ForLoops-mrvBnZIEsZY.en.csv',
#  'Lec8_MIT18.03DifferentialEquations,Spring2006-MdzfsfBNJIw.en.csv',
#  'ACoinTossingPuzzle-S_Egep9GOpQ.en.csv',
#  'Matrices-Reducedrowechelonform1_Vectorsandspaces_LinearAlgebra_KhanAcademy-L0CmbneYETs.en.csv',
#  '18.Countable-stateMarkovChainsandProcesses-_IDgYAGKyuo.en.csv',
#  'Lec28_MIT18.02MultivariableCalculus,Fall2007-WfEQabCGAqI.en.csv',
#  'Part2ofthetransformofthesin(at)_Laplacetransform_DifferentialEquations_KhanAcademy--cApVwKR1Ps.en.csv',
#  '24.Martingales-StoppingandConverging-TOvSJkC1nRI.en.csv',
#  'Determinants-B17h10EF59g.en.csv',
#  'VectorSubspaces-S8DQZjE4V8U.en.csv',
#  'Lineartransformationexamples-RotationsinR2_LinearAlgebra_KhanAcademy-lPWfIq5DzqI.en.csv',
#  'Lec34_MIT18.06LinearAlgebra,Spring2005-RWvi4Vx4CDc.en.csv',
#  '24.TopicsinAlgorithmsResearch-dU40AvBURDQ.en.csv',
#  '3.Independence-19Ql_Q3l0GA.en.csv',
#  'SimpleLists-zYVWQpCitKQ.en.csv',
#  'Uppertriangulardeterminant_Matrixtransformations_LinearAlgebra_KhanAcademy-VX7K8iqoiRc.en.csv',
#  'Advanced7-ProbabilisticandInfiniteHorizonPlanning-I2uSCTUHsUI.en.csv',
#  'Lec7_MIT6.042JMathematicsforComputerScience,Fall2010-5RSMLgy06Ew.en.csv',
#  'Methods-goalLDamePE.en.csv',
#  'Binarytreetraversal-breadth-firstanddepth-firststrategies-9RHO6jU--GU.en.csv',
#  'R9.RollingHashes,AmortizedAnalysis-w6nuXg0BISo.en.csv',
#  '14.Regression(cont.)-JBIz7UadY5M.en.csv',
#  '20.DynamicGraphsII-L7ywsci9ujo.en.csv',
#  'Lec10_MIT18.06LinearAlgebra,Spring2005-nHlE7EgJFds.en.csv',
#  'RotationinR3aroundthex-axis_Matrixtransformations_LinearAlgebra_KhanAcademy-gkyuLPzfDV0.en.csv',
#  '11.IntegerArithmetic,KaratsubaMultiplication-eCaXlAaN2uE.en.csv',
#  '2.IntroductiontoStatistics(cont.)-C_W1adH-NVE.en.csv',
#  'Relatinginvertibilitytobeingontoandone-to-one_LinearAlgebra_KhanAcademy-QIU1daMN8fw.en.csv',
#  'Lec22_MIT18.06LinearAlgebra,Spring2005-13r9QY6cmjc.en.csv',
#  'Lec22_MIT18.086MathematicalMethodsforEngineersII-zIK5EnoiLL0.en.csv',
#  'L04.6ACoinTossingExample-2f9EfEga4Oo.en.csv',
#  'Lec20_MIT6.042JMathematicsforComputerScience,Fall2010-l1BCv3qqW4A.en.csv',
#  'WhileLoops-P-0w8xWcnDQ.en.csv',
#  '12.IteratedExpectations-P7a4bjE6Crk.en.csv',
#  'Lec10_MIT18.03DifferentialEquations,Spring2006-YQ7HEE8-OfA.en.csv',
#  'im(T)-Imageofatransformation_Matrixtransformations_LinearAlgebra_KhanAcademy-hZ827mfh1Jo.en.csv',
#  'Lecture16-ExponentialDistribution_Statistics110-bM6nFDjvEns.en.csv',
#  '9.MarkovRewardsandDynamicProgramming-mNGVkKeMUtc.en.csv',
#  'Datastructures-IntroductiontoTrees-qH6yxkw0u78.en.csv',
#  'Lecture04-ErrorandNoise-L_0efNkdGMc.en.csv',
#  'L02.2ConditionalProbabilities-MPRKc4UPoJk.en.csv',
#  'Checkifabinarytreeisbinarysearchtreeornot-yEwSGhSsT0U.en.csv',
#  'Lec11_MIT6.042JMathematicsforComputerScience,Fall2010-1nScXLQAQ9A.en.csv',
#  '1.ProbabilityModelsandAxioms-j9WZyLZCBzs.en.csv',
#  'Week4-8IZ9r5kmS3Y.en.csv',
#  'R6.GreedyAlgorithms--QcPo_DWJk4.en.csv',
#  'GraphRepresentationpart01-EdgeList-ZdY1Fp9dKzs.en.csv',
#  'Lec27_MIT18.01SingleVariableCalculus,Fall2007-Bv9kVDcj7yo.en.csv',
#  "R12.KaratsubaMultiplication,Newton'sMethod-JRgIXyEPnbA.en.csv",
#  '24.Cache-ObliviousAlgorithms-Searching&Sorting-C6EWVBNCxsc.en.csv',
#  'SpecialMethods-qq7I2MQNrtU.en.csv',
#  'Lecture2-StoryProofs,AxiomsofProbability_Statistics110-FJd_1H3rZGg.en.csv',
#  '21.HypothesisTestingandRandomWalks-goT94BheP3E.en.csv',
#  'Lec6_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-hVHqs38fPe8.en.csv',
#  'Lec17_MIT18.03DifferentialEquations,Spring2006-yD0_EQLxHcw.en.csv',
#  '18.InteractingParticlesPart4-l2Q31eoy_rY.en.csv',
#  '6.FromPoissontoMarkov-cE6OD7DkCSU.en.csv',
#  'Datastructures-Introductiontographs-gXgEDyodOJU.en.csv',
#  'Exceptions-0Whyfs88TYE.en.csv',
#  'Lec14_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-le8tpXQyYcM.en.csv',
#  'InferringaDiscreteRandomVariablefromaContinuousMeasurement-96UEwIcSTG0.en.csv',
#  'Lec11_MIT18.06LinearAlgebra,Spring2005-2IdtqGM6KWU.en.csv',
#  'L04.4Combinations-o_qO7RYBF10.en.csv',
#  '12a-NeuralNets-uXt8qF2Zzfo.en.csv',
#  'Exactequationsintuition2(proofy)_Firstorderdifferentialequations_KhanAcademy-a7wYAtMjORQ.en.csv',
#  "12.RenewalRewards,StoppingTrials,andWald'sInequality-8KQR4NAl3Iw.en.csv",
#  'L03.8IndependenceVersusPairwiseIndependence-aJXfyfQs2Mc.en.csv',
#  '13.Breadth-FirstSearch(BFS)-s-CYnVz-uh4.en.csv',
#  'Lec24_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-2q--tAPkVXI.en.csv',
#  'Lec7_MIT18.086MathematicalMethodsforEngineersII-ByGXz_uHEdM.en.csv',
#  'Lec27_MIT18.06LinearAlgebra,Spring2005-vF7eyJ2g3kU.en.csv',
#  'R24.FinalExamReview-hkAONP0aC9w.en.csv',
#  'Lec23_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-raTzkzML31w.en.csv',
#  'JointProbabilityMassFunction(PMF)Drill1-81ZWzdj-I9w.en.csv',
#  'Lec32_MIT18.01SingleVariableCalculus,Fall2007-XRkgBWbWvg4.en.csv',
#  'Exampleoffindingmatrixinverse_Matrixtransformations_LinearAlgebra_KhanAcademy-r9aTLTN16V4.en.csv',
#  'Lec21_MIT18.06LinearAlgebra,Spring2005-lXNXrLcoerU.en.csv',
#  'Reversealinkedlist-Iterativemethod-sYcOK51hl-A.en.csv',
#  '23.Martingales(Plain,Sub,andSuper)-GwVjWQykCDw.en.csv',
#  'ARandomWalker-ya1braz5n88.en.csv',
#  'Lec20_MIT18.06LinearAlgebra,Spring2005-QNpj-gOXW9M.en.csv',
#  'Lecture25-OrderStatisticsandConditionalExpectation_Statistics110-2LR5JYbhyjg.en.csv',
#  'Laplacetransform2_Laplacetransform_DifferentialEquations_KhanAcademy-33TYoybjqPg.en.csv',
#  'Diracdeltafunction_Laplacetransform_DifferentialEquations_KhanAcademy-4qfdCwys2ew.en.csv',
#  '10.IntroductiontoLearning,NearestNeighbors-09mb78oiPkA.en.csv',
#  'Lec15_MIT6.042JMathematicsforComputerScience,Fall2010-TWBB-JlmYUc.en.csv',
#  '3.GeometricStructuresI-NMxLL3D5qd8.en.csv',
#  'Lecture21-CovarianceandCorrelation_Statistics110-IujCYxtpszU.en.csv',
#  'Lec25_MIT18.03DifferentialEquations,Spring2006-heBvViSi9xQ.en.csv',
#  'Lec19_MIT18.086MathematicalMethodsforEngineersII-zha1744fTRs.en.csv',
#  'Lec1_MIT18.03DifferentialEquations,Spring2006-XDhJ8lVGbl8.en.csv',
#  '13.IntegerLowerBounds-RecEYrnvGPM.en.csv',
#  '6.RecursionandDictionaries-WPSeyjX1-4s.en.csv',
#  'Lecture11-Overfitting-EQWr3GGCdzw.en.csv',
#  'DeleteanodefromBinarySearchTree-gcULXE7ViZw.en.csv',
#  'R23.ComputationalComplexity-t5Wxk96QjUk.en.csv',
#  'Pointdistancetoplane_Vectorsandspaces_LinearAlgebra_KhanAcademy-7rIFO8hct9g.en.csv',
#  'Determinantwhenrowisadded_Matrixtransformations_LinearAlgebra_KhanAcademy-VrB3LaSD_uo.en.csv',
#  'EvaluationofPrefixandPostfixexpressionsusingstack-MeRb_1bddWg.en.csv',
#  'Tuples-ncpb4wIsQu8.en.csv',
#  'Duplicaterowdeterminant_Matrixtransformations_LinearAlgebra_KhanAcademy-gYv8sttBIqs.en.csv',
#  'ADerivedDistributionExample-HwkKtHLCmzo.en.csv',
#  'Lecture34-ALookAhead_Statistics110-ChS3K2O-h7o.en.csv',
#  'Laplacetransformtosolveanequation_Laplacetransform_DifferentialEquations_KhanAcademy-3uYb-RhM7lU.en.csv',
#  "Euler'smethodprogramcode_Firstorderdifferentialequations_KhanAcademy-SJVhtIGAkKs.en.csv",
#  '18.SpeedingupDijkstra-CHvQ3q_gJ7E.en.csv',
#  'Visualizationsofleftnullspaceandrowspace_LinearAlgebra_KhanAcademy-GW8ZPjGlk24.en.csv',
#  '1.IntroductionandProbabilityReview-7CYXy9J4Aao.en.csv',
#  'Lec3_MIT18.01SingleVariableCalculus,Fall2007-kCPVBl953eY.en.csv',
#  'Compositionsoflineartransformations2_Matrixtransformations_LinearAlgebra_KhanAcademy-BuqcKpe5ZQs.en.csv',
#  'Lec31_MIT18.06LinearAlgebra,Spring2005-vGkn-3NFGck.en.csv',
#  'Lec25_MIT18.06LinearAlgebra,Spring2005-umt6BB1nJ4w.en.csv',
#  'LinkedListinC_C++-Insertinganodeatbeginning-cAZ8CyDY56s.en.csv',
#  '3.Divide&Conquer-FFT-iTMn0Kt18tg.en.csv',
#  'ConditionalProbabilityExample-6MffbP5O2v0.en.csv',
#  'InorderSuccessorinabinarysearchtree-5cPbNCrdotA.en.csv',
#  'Linearcombinationsandspan_Vectorsandspaces_LinearAlgebra_KhanAcademy-Qm_OS-8COwU.en.csv',
#  'Lecture14-TreeRecursiveNeuralNetworksandConstituencyParsing-RfwgqPkWZ1w.en.csv',
#  '15.InteractingParticlesPart1-Y59FgktB4uQ.en.csv',
#  'Lec30_MIT18.02MultivariableCalculus,Fall2007-seO7-TwXH_I.en.csv',
#  'S01.3SequencesandtheirLimits-kuhlfBPQPq0.en.csv',
#  'S01.5InfiniteSeries-nYe4OZVCnIs.en.csv',
#  'L02.5ARadarExampleandThreeBasicTools-uL31gpFdarc.en.csv',
#  'Advanced1.IncrementalPathPlanning-_4u9W1xOuts.en.csv',
#  'Lec9_MIT18.01SingleVariableCalculus,Fall2007-BSAA0akmPEU.en.csv',
#  'Lecture16-RadialBasisFunctions-O8CfrnOPtLc.en.csv',
#  '23.ModelMerging,Cross-ModalCoupling,CourseSummary-XPEJg_6Cg6o.en.csv',
#  'Lec21_MIT6.042JMathematicsforComputerScience,Fall2010-MOfhhFaQdjw.en.csv',
#  'Lec1_MIT18.06LinearAlgebra,Spring2005-ZK3O402wf1c.en.csv',
#  'Lec10_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-kDhR4Zm53zc.en.csv',
#  'Lec14_MIT18.03DifferentialEquations,Spring2006-Y9_zrupnz0Q.en.csv',
#  'Week10,continued-zHw_ks0pdWw.en.csv',
#  'Introductiontothenullspaceofamatrix_Vectorsandspaces_LinearAlgebra_KhanAcademy-jCwRV1QL_Xs.en.csv',
#  'Lec22_MIT18.01SingleVariableCalculus,Fall2007-ShGBRUx2ub8.en.csv',
#  'Lec32_MIT18.02MultivariableCalculus,Fall2007-sr7kCpzAuYw.en.csv',
#  'Solvingthelogisticdifferentialequationpart2_KhanAcademy-NU1v-8VRirU.en.csv',
#  'Binarytree-LevelOrderTraversal-86g8jAQug04.en.csv',
#  'TheProbabilityDistributionFunction(PDF)of[X]-euqZK85cQwo.en.csv',
#  'Lecture12-End-to-EndModelsforSpeechProcessing-3MjIkWxXigM.en.csv',
#  'R8.NP-CompleteProblems-G7mqtB6npfE.en.csv',
#  'R8.SimulationAlgorithms-eGSXsaJ-BlY.en.csv',
#  'Simplifyingconditionsforinvertibility_Matrixtransformations_LinearAlgebra_KhanAcademy-Yz2OosyMTmY.en.csv',
#  'Lec36_MIT18.01SingleVariableCalculus,Fall2007-KhwQKE_tld0.en.csv',
#  '9.Cache-ObliviousStructuresII-Fs4-E4Nj1Ks.en.csv',
#  '20.QuantumStatisticalMechanicsPart2-b1P0hurY6UE.en.csv',
#  'Laplacetransformoft-L{t}_Laplacetransform_DifferentialEquations_KhanAcademy-qhKJ1DG9kYY.en.csv',
#  'L04.9MultinomialProbabilities-5A_H1eHbOCY.en.csv',
#  'Lec14_MIT18.086MathematicalMethodsforEngineersII-pEuuJ5E7ZS0.en.csv',
#  'Lec33_MIT18.02MultivariableCalculus,Fall2007-BChhAS1sFvA.en.csv',
#  'Lec13_MIT6.042JMathematicsforComputerScience,Fall2010-X9eErxRjQEI.en.csv',
#  'Lec22_MIT18.02MultivariableCalculus,Fall2007-tYdoS0tkAHA.en.csv',
#  '1.ThermodynamicsPart1-4RX_lpoGRBg.en.csv',
#  '10.Dictionaries-Mf9Nn9PbGsE.en.csv',
#  'MethodCall-_ax4eNMI9Dw.en.csv',
#  'Lecture17-MomentGeneratingFunctions_Statistics110-N8O6zd6vTZ8.en.csv',
#  '13.BernoulliProcess-gMTiAeE0NCw.en.csv',
#  'Lec12_MIT18.03DifferentialEquations,Spring2006-eyNm7XGJr4s.en.csv',
#  'LUDecomposition--eA2D_rIcNA.en.csv',
#  'Lec20_MIT18.086MathematicalMethodsforEngineersII-kyx2QgGkEpc.en.csv',
#  'Firstorderhomogeneousequations2_Firstorderdifferentialequations_KhanAcademy-6YRGEsQWZzY.en.csv',
#  'L04.8EachPersonGetsAnAce-IC-pnm6PEGk.en.csv',
#  'L03.3IndependenceofTwoEvents-w423ypsUHf0.en.csv',
#  '22.RandomWalksandThresholds-K-iHODiS0-8.en.csv',
#  '1.IntroductionandScope-TjZBTDzGeGg.en.csv',
#  'Reversealinkedlistusingrecursion-KYH83T4q6Vs.en.csv',
#  'Vectorexamples_Vectorsandspaces_LinearAlgebra_KhanAcademy-r4bH66vYjss.en.csv',
#  'Lecture6-DependencyParsing-PVShkZgXznc.en.csv',
#  'Lec13_MIT18.06LinearAlgebra,Spring2005-l88D4r74gtM.en.csv',
#  'Vectordotproductandvectorlength_Vectorsandspaces_LinearAlgebra_KhanAcademy-WNuIhXo39_k.en.csv',
#  'R20.DynamicProgramming-Blackjack-jZbkToeNK2g.en.csv',
#  'Lec18_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-QJ_MPc0TobI.en.csv',
#  'L04.2TheCountingPrinciple--k8WU-KB0rk.en.csv',
#  'Week7,continued-QWnZpgZKOoc.en.csv',
#  '21.Cryptography-HashFunctions-KqqOXndnvic.en.csv',
#  'Lec10_MIT6.042JMathematicsforComputerScience,Fall2010-DOIp5D7VMS4.en.csv',
#  'Undeterminedcoefficients1_Secondorderdifferentialequations_KhanAcademy-znE4Nq9NJCQ.en.csv',
#  'Moreonmatrixadditionandscalarmultiplication_LinearAlgebra_KhanAcademy-Z19-ObbmHJE.en.csv',
#  '8.Constraints-Search,DomainReduction-d1KyYyLmGpA.en.csv',
#  'Lec8_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-ewd7Lf2dr5Q.en.csv',
#  'Exam#1ProblemSolving-AMLekTJR5_U.en.csv',
#  'Lecture08-Bias-VarianceTradeoff-zrEyxfl2-a8.en.csv',
#  'Lineartransformations_Matrixtransformations_LinearAlgebra_KhanAcademy-4PCktDZJH8E.en.csv',
#  'EigenvaluesandEigenvectors-mVeuZzJdd1w.en.csv',
#  '16.Dijkstra-2E7MmKv0Y24.en.csv',
#  'Laplacetransformoft^n-L{t^n}_Laplacetransform_DifferentialEquations_KhanAcademy-pZIaUx3UQoA.en.csv',
#  'OrthogonalVectorsandSubspaces-h9aDgvW59TU.en.csv',
#  'Lec20_MIT18.01SingleVariableCalculus,Fall2007-Pd2xP5zDsRw.en.csv',
#  '6.Randomization-MatrixMultiply,Quicksort-cNB2lADK3_s.en.csv',
#  'DataStructures-Listasabstractdatatype-HdFG8L1sajw.en.csv',
#  'JointProbabilityMassFunction(PMF)Drill2-JIOJRuzwJQw.en.csv',
#  '2.RetroactiveDataStructures-WqCWghETNDc.en.csv',
#  '22.Cryptography-Encryption-9TNI2wHmaeI.en.csv',
#  'R4.RandomizedSelectandRandomizedQuicksort-QPk8MUtq5yA.en.csv',
#  '21.IdealQuantumGasesPart1-34lmLIYpkYQ.en.csv',
#  'AMixedDistributionExample-6UdLp2gpmcE.en.csv',
#  'Transposeofamatrixproduct_Matrixtransformations_LinearAlgebra_KhanAcademy-UdHgWK13x5I.en.csv',
#  'Datastructures-BinaryTree-H5JubkIy_p8.en.csv',
#  'R2.2-3TreesandB-Trees-TOb1tuEZ2X4.en.csv',
#  'Week2-yMAvmUyrwlc.en.csv',
#  'R1.MatrixMultiplicationandtheMasterTheorem-09vU-wVwW3U.en.csv',
#  'Lecture10-NeuralMachineTranslationandModelswithAttention-IxQtK2SjWWM.en.csv',
#  'L01.8AContinuousExample-NbYB0fiHoCs.en.csv',
#  'Recitation9b-DNASequenceMatching--DwGrJ8JxDc.en.csv',
#  'R9.ApproximationAlgorithms-TravelingSalesmanProblem-zM5MW5NKZJg.en.csv',
#  'R1.AsymptoticComplexity,PeakFinding-P7frcB_-g4w.en.csv',
#  'Lec9_MIT6.042JMathematicsforComputerScience,Fall2010-bTyxpoi2dmM.en.csv',
#  'L01.1LectureOverview-1uW3qMFA9Ho.en.csv',
#  '15.StaticTrees-0rCFkuQS968.en.csv',
#  'TheDifferenceofTwoIndependentExponentialRandomVariables-f8Nli1AfygM.en.csv',
#  'UsingtheConditionalExpectationandVariance-CSkcBXUIJh4.en.csv',
#  "Euler'smethod_Differentialequations_APCalculusBC_KhanAcademy-q87L9R9v274.en.csv",
#  'Datastructures-PropertiesofGraphs-AfYqN3fGapc.en.csv',
#  'Parametricrepresentationsoflines_Vectorsandspaces_LinearAlgebra_KhanAcademy-hWhs2cIj7Cw.en.csv',
#  'Datastructures-Introductiontostack-F1F2imiOJfk.en.csv',
#  '3.Reasoning-GoalTreesandRule-BasedExpertSystems-leXa7EKUPFk.en.csv',
#  'L04.5BinomialProbabilities-8llkkbCPHb4.en.csv',
#  'Lec19_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-IZaAUwW7OsU.en.csv',
#  'Mega-R6.Boosting-ZZmzMJB-tow.en.csv',
#  'MatrixSpaces-BaBoztM9Q1w.en.csv',
#  '5.ProbabilityPart1-w_I0AkvbWFc.en.csv',
#  'Lecture23-Betadistribution_Statistics110-UZjlBQbV1KU.en.csv',
#  'R10.DistributedAlgorithms-w_-SX4vR53M.en.csv',
#  'InferringaContinuousRandomVariablefromaDiscreteMeasurement-TbC-kPbRt3c.en.csv',
#  'Laplacetransform1_Laplacetransform_DifferentialEquations_KhanAcademy-OiNh2DswFt4.en.csv',
#  "'Shifting'transformbymultiplyingfunctionbyexponential_DifferentialEquations_KhanAcademy-_X_QwpXsdOs.en.csv",
#  'Matrices-Reducedrowechelonform2_Vectorsandspaces_LinearAlgebra_KhanAcademy-lP1DGtZ8Wys.en.csv',
#  'Gram-SchmidtOrthogonalization-HEQuN0QELSQ.en.csv',
#  'R3.DocumentDistance,InsertionandMergeSort-4iXLnF3hExw.en.csv',
#  'Lecture4-WordWindowClassificationandNeuralNetworks-uc2_iwVqrRI.en.csv',
#  "Workedexample-Euler'smethod_Differentialequations_APCalculusBC_KhanAcademy-_-a-yNubpk8.en.csv",
#  'Lec19_MIT6.042JMathematicsforComputerScience,Fall2010-E6FbvM-FGZ8.en.csv',
#  'Datastructures-ArrayimplementationofQueue-okr-XE8yTO8.en.csv',
#  'R18.Quiz2Review-sPuazUPiV1k.en.csv',
#  'Undeterminedcoefficients3_Secondorderdifferentialequations_KhanAcademy-I3vIAzMcm4Y.en.csv',
#  'L03.5ConditionalIndependence-7B3cDe39lwY.en.csv',
#  'ListAliasing_Mutation-FKp-6sojt9A.en.csv',
#  '9.TableDoubling,Karp-Rabin-BRO7mVIFt08.en.csv',
#  'SolvingAx=0-3cMyj8EKFGo.en.csv',
#  'Lec6_MIT18.06LinearAlgebra,Spring2005-8o5Cmfpeo6g.en.csv',
#  '11.KineticTheoryofGasesPart5-QmV7FOXijMo.en.csv',
#  '22.GeneralizedLinearModels(cont.)-mc1y8m9-hOM.en.csv',
#  'L02.3ADieRollExample-YenDB3yOfDc.en.csv',
#  'Unitvectornotation_Vectorsandspaces_LinearAlgebra_KhanAcademy-9ylUcCOTH8Y.en.csv',
#  'Checkforbalancedparenthesesusingstack-QZOLb0xHB_Q.en.csv',
#  '8.ParametricHypothesisTesting(cont.)-4HRhg4eUiMo.en.csv',
#  'Lecture10-ExpectationContinued_Statistics110-P1fSFvhPf7Q.en.csv',
#  'Strings-w4uxYDPsjbw.en.csv',
#  '3.InsertionSort,MergeSort-Kg4bqzAqRBM.en.csv',
#  '7.Testing,Debugging,Exceptions,andAssertions-9H6muyZjms0.en.csv',
#  'SubspacesofThreeDimensionalSpace-QQpvGlF_1Qo.en.csv',
#  'Lineartransformationexamples-Scalingandreflections_LinearAlgebra_KhanAcademy-qkfODKmZ-x4.en.csv',
#  'Lec12_MIT18.01SingleVariableCalculus,Fall2007-YN7k_bXXggY.en.csv',
#  'Lec17_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-ZbIpjf0QEPI.en.csv',
#  'Lec10_MIT18.01SingleVariableCalculus,Fall2007-eRCN3daFCmU.en.csv',
#  '12.ClassicalStatisticalMechanicsPart1-ckUyxmwaC5E.en.csv',
#  '6.ProbabilityPart2-I_LcUur7quE.en.csv',
#  'S01.4WhenDoesaSequenceConverge-Lgacew5BjDI.en.csv',
#  'Lec20_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-ENrAsRoR97I.en.csv',
#  'Lec11_MIT18.086MathematicalMethodsforEngineersII-ZpOJJk6en2o.en.csv',
#  'CommunicationoveraNoisyChannel-rzg_CavQI_M.en.csv',
#  'Week1,continued-hzxRkCoymiQ.en.csv',
#  '1.AlgorithmicThinking,PeakFinding-HtSuA80QTyo.en.csv',
#  'Lec16_MIT18.03DifferentialEquations,Spring2006-xWa5_OXI6VM.en.csv',
#  'Lecture06-TheoryofGeneralization-6FWRijsmLtE.en.csv',
#  '7.CountingSort,RadixSort,LowerBoundsforSorting-Nz1KZXbghj8.en.csv',
#  'Lec5_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-Pfo7r6bjSqI.en.csv',
#  'TheAbsentMindedProfessor-X5ch4xZf3LE.en.csv',
#  '14.Depth-FirstSearch(DFS),TopologicalSort-AfSk24UTFS8.en.csv',
#  'Rec1_MIT18.085ComputationalScienceandEngineeringI,Fall2008-0oBJN8F616U.en.csv',
#  'Normalvectorfromplaneequation_Vectorsandspaces_LinearAlgebra_KhanAcademy-gw-4wltP5tY.en.csv',
#  "2.ConditioningandBayes'Rule-TluTv5V0RmE.en.csv",
#  'Showingrelationbetweenbasiscolsandpivotcols_LinearAlgebra_KhanAcademy-BfVjTOjvI30.en.csv',
#  'GeniusesandChocolates-y7lV5jwK27E.en.csv',
#  'R14.Depth-FirstSearch(DFS)-C5SPsY72_CM.en.csv',
#  'Shellvs.Editor-Y6J8I056Ffw.en.csv',
#  'ProofoftheCauchy-Schwarzinequality_Vectorsandspaces_LinearAlgebra_KhanAcademy-r2PogGDl8_U.en.csv',
#  'Week5,continued-atBMLJdSKBo.en.csv',
#  'Determiningwhetheratransformationisonto_LinearAlgebra_KhanAcademy-eR8vEdJTvd0.en.csv',
#  'Lec12_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-udnyuHzJsjM.en.csv',
#  'Lec17_MIT18.086MathematicalMethodsforEngineersII-Y25UBGeu_2g.en.csv',
#  '5.MaximumLikelihoodEstimation(cont.)-0Va2dOLqUfM.en.csv',
#  'Lec29_MIT18.06LinearAlgebra,Spring2005-Nx0lRBaXoz4.en.csv',
#  'Lecture2_WordVectorRepresentations-word2vec-ERibwqs9p38.en.csv',
#  'Complexrootsofthecharacteristicequations1_Secondorderdifferentialequations_KhanAcademy-6xEO4BeawzA.en.csv',
#  'Proof-Invertibilityimpliesauniquesolutiontof(x)=y_LinearAlgebra_KhanAcademy-7GEUgRcnfVE.en.csv',
#  'Lec24_MIT18.03DifferentialEquations,Spring2006-MCrDzhpu3-s.en.csv',
#  'DifferentialEquationsandexp(At)-FzncDO1eSNI.en.csv',
#  '9.ParametricHypothesisTesting(cont.)-QXkOaifVfW4.en.csv',
#  'Lec35_MIT18.02MultivariableCalculus,Fall2007-24v9onS9Kcg.en.csv',
#  'Lec15_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-y81AhLQN-NI.en.csv',
#  'L03.9Reliability-UDkq_cLVSmc.en.csv',
#  'Lec28_MIT18.01SingleVariableCalculus,Fall2007-CXKoCMVqM9s.en.csv',
#  'Datastructures-BinarySearchTree-pYT9F8_LFTM.en.csv',
#  'Lecture18-TacklingtheLimitsofDeepLearningforNLP-JYwNmSe4HqE.en.csv',
#  'Lec12_MIT6.042JMathematicsforComputerScience,Fall2010-fAeShezAGLE.en.csv',
#  'Lec22_MIT18.03DifferentialEquations,Spring2006-_YVcjNmjHik.en.csv',
#  'Basisofasubspace_Vectorsandspaces_LinearAlgebra_KhanAcademy-zntNi3-ybfQ.en.csv',
#  'Lecture3_GloVe-GlobalVectorsforWordRepresentation-ASn7ExxLZws.en.csv',
#  'Vectortripleproductexpansion(veryoptional)_Vectorsandspaces_LinearAlgebra_KhanAcademy-b7JTVLc_aMk.en.csv',
#  'Lec4_MIT18.02MultivariableCalculus,Fall2007-YBajUR3EFSM.en.csv',
#  'Lec20_MIT18.02MultivariableCalculus,Fall2007-o7UCBjGsRTE.en.csv',
#  'Differentialequationintroduction_Firstorderdifferentialequations_KhanAcademy-6o7b9yyhH7k.en.csv',
#  'Errors--wz4iU2V-Yo.en.csv',
#  '9.Constraints-VisualObjectRecognition-gvmfbePC2pc.en.csv',
#  'Lec7_MIT18.02MultivariableCalculus,Fall2007-U1EcnfTKXJ0.en.csv',
#  'Lec24_MIT18.02MultivariableCalculus,Fall2007-PnPIqh7Frlw.en.csv',
#  '(correction)scalarmultiplicationofrow_Matrixtransformations_LinearAlgebra_KhanAcademy-WY6QG0mZ7uQ.en.csv',
#  '3.StringManipulation,GuessandCheck,Approximations,Bisection-SE4P7IVCunE.en.csv',
#  'Lec37_MIT18.01SingleVariableCalculus,Fall2007-MK_0QHbUnIA.en.csv',
#  'Realcoordinatespaces_Vectorsandspaces_LinearAlgebra_KhanAcademy-lCsjJbZHhHU.en.csv',
#  'Mega-R4.NeuralNets-JMrFgnqSS0w.en.csv',
#  'Lecture28-Inequalities_Statistics110-UtXK_EQ3Pow.en.csv',
#  '17.Countable-stateMarkovChains-s98jdWi2kEs.en.csv',
#  'Lec8_MIT6.042JMathematicsforComputerScience,Fall2010-GJpt_3ie4WU.en.csv',
#  '4.Decomposition,Abstraction,andFunctions-MjbuarJ7SE0.en.csv',
#  'Lec17_MIT18.06LinearAlgebra,Spring2005-uNsCkP9mgRk.en.csv',
#  '5.Search-Optimal,BranchandBound,A-gGQ-vAmdAOI.en.csv',
#  'Advanced3.ImageClassificationviaDeepLearning-DdPNsGRIw6o.en.csv',
#  'Lecture16-DynamicNeuralNetworksforQuestionAnswering-T3octNTE7Is.en.csv',
#  'Lec27_MIT18.03DifferentialEquations,Spring2006-e3FfmXtkppM.en.csv',
#  '18.Complexity-Fixed-ParameterAlgorithms-4q-jmGrmxKs.en.csv',
#  'Amoreformalunderstandingoffunctions_Matrixtransformations_LinearAlgebra_KhanAcademy-BQMyeQOLvpg.en.csv',
#  'Lec29_MIT18.03DifferentialEquations,Spring2006-zreI4HllD80.en.csv',
#  'InfixtoPostfixusingstack-vq-nUF0G4fI.en.csv',
#  'Lec30_MIT18.03DifferentialEquations,Spring2006-uNOyxQwIV8o.en.csv',
#  '4.ParametricInference(cont.)andMaximumLikelihoodEstimation-rLlZpnT02ZU.en.csv',
#  'Imageofasubsetunderatransformation_Matrixtransformations_LinearAlgebra_KhanAcademy-MIAmN5kgp3k.en.csv',
#  '12.TestingGoodnessofFit(cont.)-vMaKx9fmJHE.en.csv',
#  'Lec22_MIT6.042JMathematicsforComputerScience,Fall2010-gGlMSe7uEkA.en.csv',
#  'Infix,PrefixandPostfix-jos1Flt21is.en.csv',
#  'Lec7_MIT18.03DifferentialEquations,Spring2006-SioXozu-Loo.en.csv',
#  'L04.7Partitions-hJjiCrdsNV8.en.csv',
#  'Lec2_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-Pij6J0HsYFA.en.csv',
#  'Mega-R5.SupportVectorMachines-6nDqY8MPLDM.en.csv',
#  'L01.6MorePropertiesofProbabilities-N3I2ZLbh6zQ.en.csv',
#  "Newton'sLawofCooling_Firstorderdifferentialequations_KhanAcademy-IICR-w1jYcA.en.csv",
#  'R13.Breadth-FirstSearch(BFS)-5JxShDZ_ylo.en.csv',
#  'TheVarianceintheStickBreakingProblem-NlRgBtSLViI.en.csv',
#  '3.LawofLargeNumbers,Convergence-k0UZNZwPO8Q.en.csv',
#  'Lec9_MIT18.03DifferentialEquations,Spring2006-vP-oRQqmeg4.en.csv',
#  'Lec15_MIT18.03DifferentialEquations,Spring2006-EWWw0jryj1A.en.csv',
#  'BlackBoxandGlassBoxTesting-5McjE8e5gIg.en.csv',
#  'Lecture7-IntroductiontoTensorFlow-PicxU81owCs.en.csv',
#  'Lec18_MIT18.06LinearAlgebra,Spring2005-srxexLishgY.en.csv',
#  'R19.DynamicProgramming-CrazyEights,ShortestPath-IFrvgSvZA0I.en.csv',
#  'Moreonlinearindependence_Vectorsandspaces_LinearAlgebra_KhanAcademy-Alhcv5d_XOs.en.csv',
#  'Determinantwhenrowmultipliedbyscalar_Matrixtransformations_LinearAlgebra_KhanAcademy-32rdijPB-rA.en.csv',
#  'Exactequationsexample2_Firstorderdifferentialequations_KhanAcademy-utQi1ZhF__Q.en.csv',
#  '7.Randomization-SkipLists-2g9OSRKJuzM.en.csv',
#  '15.Single-SourceShortestPathsProblem-Aa2sqUhIn-E.en.csv',
#  'Lec14_MIT18.06LinearAlgebra,Spring2005-YzZUIYRCE38.en.csv',
#  "12.SquareRoots,Newton'sMethod-2YeJ-5UAke8.en.csv",
#  'Proof-Anysubspacebasishassamenumberofelements_LinearAlgebra_KhanAcademy-Zn2K8UIT8r4.en.csv',
#  'SamplingPeopleonBuses-0MrkYxOg_Vo.en.csv',
#  '4.Divide&Conquer-vanEmdeBoasTrees-hmReJCupbNU.en.csv',
#  'NetworkReliability-PqZj8pySQiU.en.csv',
#  '7.KineticTheoryofGasesPart1-BhVyiU_dWps.en.csv',
#  '15.Regression(cont.)-V4xOdtqic3o.en.csv',
#  'Lec14_MIT18.01SingleVariableCalculus,Fall2007-4Q37iOyBq44.en.csv',
#  'NormalProbabilityCalculation-62KrMWdX-RU.en.csv',
#  'Laplacetransformoftheunitstepfunction_Laplacetransform_KhanAcademy-4Mr7aEHQr8E.en.csv',
#  'Lec15_MIT18.01SingleVariableCalculus,Fall2007--MI0b4h3rS0.en.csv',
#  'Lineartransformationsasmatrixvectorproducts_LinearAlgebra_KhanAcademy-PErhLkQcpZ8.en.csv',
#  'Lec21_MIT18.086MathematicalMethodsforEngineersII-7dVYOOHB4g4.en.csv',
#  '17.InteractingParticlesPart3-TSjJlJJ2aoI.en.csv',
#  '12.GreedyAlgorithms-MinimumSpanningTree-tKwnms5iRBU.en.csv',
#  'Lec13_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-ZKBUu_ahSR4.en.csv',
#  'UsingtheLaplacetransformtosolveanonhomogeneouseq_Laplacetransform_KhanAcademy-nlUG4OKN1IY.en.csv',
#  'S01.0MathematicalBackgroundOverview--630YTQEuCI.en.csv',
#  'Lec9_MIT18.06LinearAlgebra,Spring2005-yjBerM5jWsc.en.csv',
#  'Lec16_MIT6.042JMathematicsforComputerScience,Fall2010-pNt5Ll6hGqo.en.csv',
#  '17.Complexity-ApproximationAlgorithms-MEz1J9wY2iM.en.csv',
#  'Distributivepropertyofmatrixproducts_Matrixtransformations_LinearAlgebra_KhanAcademy-oMWTMj78cwc.en.csv',
#  'Lec12_MIT18.02MultivariableCalculus,Fall2007-2XraaWefBd8.en.csv',
#  '18.BayesianStatistics(cont.)-k2inA31Gups.en.csv',
#  'AChessTournamentProblem-eilGapl5cz8.en.csv',
#  "Lecture6-MontyHall,Simpson'sParadox_Statistics110-fDcjhAKuhqQ.en.csv",
#  'Determinantsalongotherrows_cols_Matrixtransformations_LinearAlgebra_KhanAcademy-nu87kfmwNfU.en.csv',
#  'L01.7ADiscreteExample-AsSQdpZdP8U.en.csv',
#  '20.PrincipalComponentAnalysis(cont.)-a1ZCeFpeW0o.en.csv',
#  'Pythonvs.Math-F-_PKUUM-qY.en.csv',
#  'DataStructures-LinkedListimplementationofstacks-MuwxQ2IB8lQ.en.csv',
#  'TheCouponCollectorProblem-3mu47FWEuqA.en.csv',
#  'Lecture05-TrainingVersusTesting-SEYAnnLazMU.en.csv',
#  'Lec5_MIT18.03DifferentialEquations,Spring2006-te6Mplq3DCU.en.csv',
#  'Laplacetransformofcostandpolynomials_Laplacetransform_KhanAcademy-fyJkXBvcA2Q.en.csv',
#  'Lec28_MIT18.03DifferentialEquations,Spring2006-2SuTN8rpe4I.en.csv',
#  '8.KineticTheoryofGasesPart2-8woIHrY6eM0.en.csv',
#  '25.PuttingItAllTogether-mq3nFovdG3o.en.csv',
#  'Datastructures-IntroductiontoQueues-XuCbpw6Bj1U.en.csv',
#  '19.Countable-stateMarkovProcesses-ImKFBTqLqdE.en.csv',
#  '8.HashingwithChaining-0M_kIqhwbFo.en.csv',
#  'LinkedListinC_C++-Deleteanodeatnthposition-Y0n86K43GO4.en.csv',
#  'Lecture14-Location,Scale,andLOTUS_Statistics110-9vp1Ll2NpRw.en.csv',
#  'Lecture01-TheLearningProblem-mbyG85GZ0PI.en.csv',
#  'ARandomNumberofCoinFlips-NYOcZx6Kxsw.en.csv',
#  'FlippingaCoinaRandomNumberofTimes-7zjuscCceR8.en.csv',
#  'CalculatingaCumulativeDistributionFunction(CDF)-wQ6Q9W3Y1ZE.en.csv',
#  'Lec23_MIT18.01SingleVariableCalculus,Fall2007-R9a_NHXrBcg.en.csv',
#  'DeterminantsandVolume-qEBi0K5wfOs.en.csv',
#  'Lec4FactorizationintoA=LU-MsIvs_6vC38.en.csv',
#  'Undeterminedcoefficients2_Secondorderdifferentialequations_KhanAcademy-hbJ2o9EUmJ0.en.csv',
#  'Lec21_MIT18.02MultivariableCalculus,Fall2007-z5TPjZrsp2k.en.csv',
#  'AnOverviewofKeyIdeas-OZxzHcW663g.en.csv',
#  '10.OpenAddressing,CryptographicHashing-rvdJDijO2Ro.en.csv',
#  'Lec23_MIT6.042JMathematicsforComputerScience,Fall2010-oI9fMUqgfxY.en.csv',
#  'Lec27_MIT18.02MultivariableCalculus,Fall2007-phk05iSMezA.en.csv',
#  'Lec31_MIT18.01SingleVariableCalculus,Fall2007-TpWQlKHPyJ4.en.csv',
#  '18.SuccinctStructuresII-ABX-Hvn8ymE.en.csv',
#  '2.Reasoning-GoalTreesandProblemSolving-PNKj529yY5c.en.csv',
#  'Lec21_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-SuOIpJnn888.en.csv',
#  'Week9-doxwwYKvlfw.en.csv',
#  'Lec15_MIT18.02MultivariableCalculus,Fall2007-ChiM2-MV-qM.en.csv',
#  '24.GeneralizedLinearModels(cont.)-lWW54ts9Ubo.en.csv',
#  '5.BinarySearchTrees,BSTSort-9Jry5-82I68.en.csv',
#  'Proof-Relationshipbetweencrossproductandsinofangle_LinearAlgebra_KhanAcademy-7MKA2QlKvHc.en.csv',
#  'Laplacetransformofthediracdeltafunction_Laplacetransform_KhanAcademy-vhfjEpQWWeE.en.csv',
#  'Lec38_MIT18.01SingleVariableCalculus,Fall2007-wOHrNt9ScYs.en.csv',
#  'DefiningaplaneinR3withapointandnormalvector_LinearAlgebra_KhanAcademy-UJxgcVaNTqY.en.csv',
#  'Lec7-Exam1review_MIT18.01SingleVariableCalculus,Fall2007-eHJuAByQf5A.en.csv',
#  'Mega-R3.Games,Minimax,Alpha-Beta-hM2EAvMkhtk.en.csv',
#  'ForLoopsWithStrings-4WtaFLayz_w.en.csv',
#  'Lecture14-SupportVectorMachines-eHsErlPJWUU.en.csv',
#  '4.Counting-6oV3pKLgW2I.en.csv',
#  '8.MarkovEigenvaluesandEigenvectors-GCFd0VVnWTw.en.csv',
#  "L02.8Bayes'Rule-kz2tvO_ZAKI.en.csv",
#  'Dimensionofthenullspaceornullity_Vectorsandspaces_LinearAlgebra_KhanAcademy-abYAUqs_n6I.en.csv',
#  'Lecture12-Discretevs.Continuous,theUniform_Statistics110-Tci---bVs60.en.csv',
#  'Lecture12-Regularization-I-VfYXzC5ro.en.csv',
#  'Lec39_MIT18.01SingleVariableCalculus,Fall2007---lPz7VFnKI.en.csv',
#  'Vectortriangleinequality_Vectorsandspaces_LinearAlgebra_KhanAcademy-PsNidCBr5II.en.csv',
#  '21.ProbabilisticInferenceI-A6Ud6oUCRak.en.csv',
#  '9.KineticTheoryofGasesPart3-t7pTpwMjQ5I.en.csv',
#  'Lecture15-CoreferenceResolution-rpwEWLaueRk.en.csv',
#  'Exactequationsintuition1(proofy)_Firstorderdifferentialequations_KhanAcademy-iEpqcdaJNTQ.en.csv',
#  'Matrices-Reducedrowechelonform3_Vectorsandspaces_LinearAlgebra_KhanAcademy-JVDrlTdzxiI.en.csv',
#  'Lecture31-MarkovChains_Statistics110-8AJPs3gvNlY.en.csv',
#  'Lecture15-KernelMethods-XUj5JbQihlU.en.csv',
#  'SolvingAx=b-fjsPjh0B2tU.en.csv',
#  'WidgetsandCrates-Y8zx1tWEbeI.en.csv',
#  '5.DiscreteRandomVariablesI-3MOahpLxj6A.en.csv',
#  '22.DPIV-GuitarFingering,Tetris,SuperMarioBros.-tp4_UXaVyx8.en.csv',
#  'Lec9_MIT18.02MultivariableCalculus,Fall2007-UYe98CcxPbs.en.csv',
#  '2ndOrderLinearHomogeneousDifferentialEquations4_KhanAcademy-3uO_uPb9H8w.en.csv',
#  'Determinantandareaofaparallelogram_Matrixtransformations_LinearAlgebra_KhanAcademy-n-S63_goDFg.en.csv',
#  'TheMontyHallProblem-UgKrQ2ywVfs.en.csv',
#  'Lec1_MIT6.042JMathematicsforComputerScience,Fall2010-L3LMbpZIKhQ.en.csv',
#  '19.QuantumStatisticalMechanicsPart1-hl4c1P9D8IY.en.csv',
#  '1.WhatisComputation-ytpJdnlu9ug.en.csv',
#  'Lecture8-RecurrentNeuralNetworksandLanguageModels-Keqep_PKrY8.en.csv',
#  'L03.6IndependenceVersusConditionalIndependence-TAyA-rjmesQ.en.csv',
#  '5.DynamicOptimalityI-DZ7jt1F8KKw.en.csv',
#  'Lec2_MIT18.01SingleVariableCalculus,Fall2007-ryLdyDrBfvI.en.csv',
#  'Lecture11-GatedRecurrentUnitsandFurtherTopicsinNMT-6_MO12fPC-0.en.csv',
#  '9.PythonClassesandInheritance-FlGjISF3l78.en.csv',
#  'Lecture1-ProbabilityandCounting_Statistics110-KbB0FjPg0mw.en.csv',
#  '6.WaveProfiles,HeatEquation_pointsource-ZPmBMd6OZeQ.en.csv',
#  'Week3,continued-YxgI7ll4Xtg.en.csv',
#  '2ndorderlinearhomogeneousdifferentialequations2_KhanAcademy-SPVqgkOZMAc.en.csv',
#  '8.ObjectOrientedProgramming--DP1i2ZU9gk.en.csv',
#  'Lec19_MIT18.02MultivariableCalculus,Fall2007-xrypSZU8cBE.en.csv',
#  'Lec4_MIT18.03DifferentialEquations,Spring2006-WBJ_iXudb-s.en.csv',
#  '11.ParametricHypothesisTesting(cont.)andTestingGoodnessofFit-a66tfLdr6oY.en.csv',
#  'CourseIntroduction_MIT18.06SCLinearAlgebra-hNDFwVVKVk0.en.csv',
#  'Datastructures-LinkedListimplementationofQueue-A5_XdiK4J8A.en.csv',
#  'Week7-RUAsmwYC2mc.en.csv',
#  'Linearsubspaces_Vectorsandspaces_LinearAlgebra_KhanAcademy-pMFv6liWK4M.en.csv',
#  'Lec25_MIT18.086MathematicalMethodsforEngineersII-j-C6QC5ufSw.en.csv',
#  '7.Constraints-InterpretingLineDrawings-l-tzjenXrvI.en.csv',
#  'Differentialequationfromslopefield_Firstorderdifferentialequations_KhanAcademy-sU5MCM3npXU.en.csv',
#  'Lec4_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-SXR9CDof7qw.en.csv',
#  '16.InteractingParticlesPart2-TDnfhpAZBqs.en.csv',
#  'Lec26_MIT18.06LinearAlgebra,Spring2005-M0Sa8fLOajA.en.csv',
#  '1.PersistentDataStructures-T0yzrZL1py0.en.csv',
#  'Introductiontolinearindependence_Vectorsandspaces_LinearAlgebra_KhanAcademy-CrV1xCWdY-g.en.csv',
#  'Lec23_MIT18.086MathematicalMethodsforEngineersII-94nmfDkTL-E.en.csv',
#  'Week3-xqhcVALTw54.en.csv',
#  'BSTimplementation-memoryallocationinstackandheap-hWokyBoo0aI.en.csv',
#  '2.Divide&Conquer-ConvexHull,MedianFinding-EzeYI7p9MjU.en.csv',
#  'Lecture15-MidtermReview_Statistics110-yFRZf81sB5k.en.csv',
#  'Lec7_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-tuRYbBvOMRo.en.csv',
#  'Lec11_MIT18.01SingleVariableCalculus,Fall2007-twzGBqPeW0M.en.csv',
#  'Lec30_MIT18.06LinearAlgebra,Spring2005-Ts3o2I8_Mxc.en.csv',
#  'Lec23_MIT18.03DifferentialEquations,Spring2006-peYvLk_HZdw.en.csv',
#  'ACoinwithRandomBias-aGyJO6G3mxQ.en.csv',
#  'ShowingthatA-transposexAisinvertible_Matrixtransformations_LinearAlgebra_KhanAcademy-ESSMQH6Y5OA.en.csv',
#  '3.ThermodynamicsPart3-JaEqS1ozlHY.en.csv',
#  'Laplacetransformsolvesanequation2_Laplacetransform_DifferentialEquations_KhanAcademy-EdQ7Q9VoF44.en.csv',
#  'Lec13_MIT18.02MultivariableCalculus,Fall2007-15HVevXRsBA.en.csv',
#  'Simpler4x4determinant_Matrixtransformations_LinearAlgebra_KhanAcademy-QV0jsTiobU4.en.csv',
#  'Lec3_MIT6.042JMathematicsforComputerScience,Fall2010-NuGDkmwEObM.en.csv',
#  'Lec6_MIT18.03DifferentialEquations,Spring2006-EQJBp6Ym-6A.en.csv',
#  "S01.2DeMorgan'sLaws-pdR9hV8mRWE.en.csv",
#  '6.DynamicOptimalityII-NoOYvZvH_FU.en.csv',
#  'Advanced5.Reachability-qgL0cA7GkJo.en.csv',
#  'Lecture03-TheLinearModelI-FIbVs5GbBlQ.en.csv',
#  'S01.7AbouttheOrderofSummationinSerieswithMultipleIndices-9QJt03983Gg.en.csv',
#  '8.ContinuousRandomVariables-mHfn_7ym6to.en.csv',
#  'Lecture09-TheLinearModelII-qSTHZvN8hzs.en.csv',
#  'Lec8_MIT18.06LinearAlgebra,Spring2005-9Q1q7s1jTzU.en.csv',
#  'Lec29_MIT18.086MathematicalMethodsforEngineersII-NEsObJTwDXI.en.csv',
#  'R7.ComparisonSort,CountingandRadixSort-9bkvws_vqLU.en.csv',
#  'Nullspace2-Calculatingthenullspaceofamatrix_LinearAlgebra_KhanAcademy-qvyboGryeA8.en.csv',
#  '24.IdealQuantumGasesPart4-FmylhZqFXNk.en.csv',
#  '6.DiscreteRandomVariablesII--qCEoqpwjf4.en.csv',
#  'Columnspaceofamatrix_Vectorsandspaces_LinearAlgebra_KhanAcademy-st6D5OdFV9M.en.csv',
#  '26.IdealQuantumGasesPart6-6gMgNriK1Nk.en.csv',
#  '7.MemoryHierarchyModels-V3omVLzI0WE.en.csv',
#  'R5.RecursionTrees,BinarySearchTrees-r5pXu1PAUkI.en.csv',
#  'L01.4ProbabilityAxioms-pA83XtLeVig.en.csv',
#  'Binarytreetraversal-Preorder,Inorder,Postorder-gm8DUJJhmY4.en.csv',
#  'Nullspaceandcolumnspacebasis_Vectorsandspaces_LinearAlgebra_KhanAcademy-_uTAdf_AsfQ.en.csv',
#  'Lecture18-MGFsContinued_Statistics110-tVDdx6xUOcs.en.csv',
#  'nxndeterminant_Matrixtransformations_LinearAlgebra_KhanAcademy-H9BWRYJNIv4.en.csv',
#  "R16.Rubik'sCube,StarCraftZero-oRpERQA4Vik.en.csv",
#  'Math2B.Calculus.Lecture03.DefiniteIntegral.-nqHLEhz5DXY.en.csv',
#  'Complexrootsofthecharacteristicequations3_Secondorderdifferentialequations_KhanAcademy-rGaM6pwqhB0.en.csv',
#  '19.DynamicProgrammingI-Fibonacci,ShortestPaths-OQ5jsbhAv_M.en.csv',
#  'Lec18_MIT18.086MathematicalMethodsforEngineersII-vIydsgrYGIY.en.csv',
#  '23.IdealQuantumGasesPart3-8kNP_VWmfFs.en.csv',
#  'Lecture13-Validation-o7zzaKd0Lkk.en.csv',
#  'Lecture1_NaturalLanguageProcessingwithDeepLearning-OQQ-W_63UgQ.en.csv',
#  'StringManipulations--jjUoTiaSHw.en.csv',
#  'R22.DynamicProgramming-DanceDanceRevolution-PptQgy89cN8.en.csv',
#  'Preimageandkernelexample_Matrixtransformations_LinearAlgebra_KhanAcademy-6yrPU8rYOhs.en.csv',
#  '10.KineticTheoryofGasesPart4-ybCsMYk5xMg.en.csv',
#  'L01.9CountableAdditivity-mUxg3j_h5GM.en.csv',
#  'UniformProbabilitiesonaTriangle-v8N6l9RXbOM.en.csv',
#  'Reverseastringorlinkedlistusingstack.-hNP72JdOIgY.en.csv',
#  'Lecture9-MachineTranslationandAdvancedRecurrentLSTMsandGRUs-QuELiw8tbx8.en.csv',
#  'Lecture11-ThePoissondistribution_Statistics110-TD1N4hxqMzY.en.csv',
#  'Lecture13-Normaldistribution_Statistics110-72QjzHnYvL0.en.csv',
#  'Lecture20-MultinomialandCauchy_Statistics110-xiVWNkQUqKk.en.csv',
#  'Lec24_MIT18.086MathematicalMethodsforEngineersII-c9XosfcouiM.en.csv',
#  'Introductiontodatastructures-92S4zgXN17o.en.csv',
#  'Dimensionofthecolumnspaceorrank_Vectorsandspaces_LinearAlgebra_KhanAcademy-JUgrBkPteTg.en.csv',
#  '20.MarkovProcessesandRandomWalks-hzJpaNcAoko.en.csv',
#  'L01.2SampleSpace-iQ2edOqEQAs.en.csv',
#  'Matrixvectorproducts_Vectorsandspaces_LinearAlgebra_KhanAcademy-7Mo4S2wyMg4.en.csv',
#  'DoublyLinkedList-ImplementationinC_C++-VOQNf1VxU3Q.en.csv',
#  '16.Learning-SupportVectorMachines-_PwhiWxHK8o.en.csv',
#  '3x3determinant_Matrixtransformations_LinearAlgebra_KhanAcademy-0c7dt2SQfLw.en.csv',
#  'Lec11_MIT18.02MultivariableCalculus,Fall2007-7eZVshlT33Q.en.csv',
#  '16.RenewalsandCountable-stateMarkov-k2PjTm1JyuI.en.csv',
#  'Lec13_MIT18.01SingleVariableCalculus,Fall2007-sRIDVAcoG5A.en.csv',
#  'LeastSquaresApproximation-AmQcoopBUTk.en.csv',
#  '5.Amortization-AmortizedAnalysis-3MpzavN3Mco.en.csv',
#  '6.Search-Games,Minimax,andAlpha-Beta-STjW3eH0Cik.en.csv',
#  '15.LinearProgramming-LP,reductions,Simplex-WwMz2fJwUCg.en.csv',
#  'Lecture07-TheVCDimension-Dc0sr0kdBVI.en.csv',
#  'Usingtheconvolutiontheoremtosolveaninitialvalueprob_Laplacetransform_KhanAcademy-rfyq32mHcYs.en.csv',
#  'BasisandDimension-MMWqGD4Urso.en.csv',
#  'Repeatedrootsofthecharacteristicequation_Secondorderdifferentialequations_KhanAcademy-NW9JfMvIsxw.en.csv',
#  'Lec3_MIT18.086MathematicalMethodsforEngineersII-dxNyJxI_2eI.en.csv',
#  'Lec8_MIT18.02MultivariableCalculus,Fall2007-dK3NEf13nPc.en.csv',
#  'ShowingthatthecandidatebasisdoesspanC(A)_Vectorsandspaces_LinearAlgebra_KhanAcademy-CkQOCnLWPUA.en.csv',
#  'Lec14_MIT18.02MultivariableCalculus,Fall2007-23xbkrpQuAo.en.csv',
#  'Mega-R1.Rule-BasedSystems-iusTmgQyZ44.en.csv',
#  'Lecture26-ConditionalExpectationContinued_Statistics110-PgawcWisb0I.en.csv',
#  'Introductiontotheconvolution_Laplacetransform_DifferentialEquations_KhanAcademy-IW4Reburjpc.en.csv',
#  'Lec25_MIT18.02MultivariableCalculus,Fall2007-44R5HgbrUmc.en.csv',
#  'Advanced2.SemanticLocalization-0wxS1iBHG9U.en.csv',
#  'Showingthatinversesarelinear_Matrixtransformations_LinearAlgebra_KhanAcademy-mr9Tow8hpCg.en.csv',
#  'Lec20_MIT18.03DifferentialEquations,Spring2006-qZHseRxAWZ8.en.csv',
#  '17.SuccinctStructuresI-3Y2weLDiUWw.en.csv',
#  'Lecture24-GammadistributionandPoissonprocess_Statistics110-Qjeswpm0cWY.en.csv',
#  'Slopefieldtovisualizesolutions_Firstorderdifferentialequations_KhanAcademy-LoaagZPWvpM.en.csv',
#  '20.DynamicProgrammingII-TextJustification,Blackjack-ENyox7kNKeY.en.csv',
#  'Lec18_MIT18.02MultivariableCalculus,Fall2007-UZb9hZIAvL4.en.csv',
#  'Expressingaprojectionontoalineasamatrixvectorprod_LinearAlgebra_KhanAcademy-JK-8XNIoAkI.en.csv',
#  '12b-DeepNeuralNets-VrMHA3yX_QI.en.csv',
#  'Lec16_MIT18.01SingleVariableCalculus,Fall2007-60VGKnYBpbg.en.csv',
#  '14.Learning-SparseSpaces,Phonology-L73hY1pBcQI.en.csv',
#  'Branching-jjbWNcIjmzc.en.csv',
#  '11.IntegerModels-u-HHY1ylhHY.en.csv',
#  'Complexrootsofthecharacteristicequations2_Secondorderdifferentialequations_KhanAcademy-jJyRrIZ595c.en.csv',
#  'Comparisons-lniF6ys2CIk.en.csv',
#  'Lecture3-BirthdayProblem,PropertiesofProbability_Statistics110-LZ5Wergp_PA.en.csv',
#  'Week2,continued-i42GUZbKTPU.en.csv',
#  'Introductiontolinkedlist-NobHlGUjV3g.en.csv',
#  'GraphRepresentationpart02-AdjacencyMatrix-9C2cpQZVRBA.en.csv',
#  'HypergeometricProbabilities-3gCQ6-yitFc.en.csv',
#  'InverseLaplaceexamples_Laplacetransform_DifferentialEquations_KhanAcademy-BbqbvSig6Mc.en.csv',
#  'R10.Quiz1Review--FElVPKykgw.en.csv',
#  'Lec9_MIT6.00IntroductiontoComputerScienceandProgramming,Fall2008-UNHQ7CRsEtU.en.csv',
#  'PropertiesofDeterminants-55AoWKZZtww.en.csv',
#  'Lec18_MIT6.042JMathematicsforComputerScience,Fall2010-SmFwFdESMHI.en.csv',
#  'Transposeofavector_Matrixtransformations_LinearAlgebra_KhanAcademy-lSoaMCNKfAg.en.csv',
#  'Lec3_MIT18.02MultivariableCalculus,Fall2007-bHdzkFrgRcA.en.csv',
#  'Lec23_MIT18.06LinearAlgebra,Spring2005-IZqwi0wJovM.en.csv',
#  'Lec2_MIT18.086MathematicalMethodsforEngineersII-nlO9ci0kPLg.en.csv',
#  'Lecture29-LawofLargeNumbersandCentralLimitTheorem_Statistics110-OprNqnHsVIA.en.csv',
#  'ClassDefinition-vqn_yk5aFcI.en.csv',
#  'Lec25_MIT18.01SingleVariableCalculus,Fall2007-zUEuKrxgHws.en.csv',
#  'Lecture17-ThreeLearningPrinciples-EZBUDG12Nr0.en.csv',
#  'Lec2_MIT6.042JMathematicsforComputerScience,Fall2010-z8HKWUWS-lA.en.csv',
#  '18.Representations-Classes,Trajectories,Transitions-bQI0OmJPby4.en.csv',
#  'GraphsandNetworks-h0m2tsmSPTI.en.csv',
#  'Lec13_MIT18.086MathematicalMethodsforEngineersII-S6dw885-SZI.en.csv',
#  'Definingtheanglebetweenvectors_Vectorsandspaces_LinearAlgebra_KhanAcademy-5AWob_z74Ks.en.csv',
#  'PMFofaFunctionofaRandomVariable-Qx2NKaUCUw0.en.csv',
#  'Determinantafterrowoperations_Matrixtransformations_LinearAlgebra_KhanAcademy-kpG7xySkivg.en.csv',
#  'Lec11_MIT18.03DifferentialEquations,Spring2006-rZ3-nFV6l8w.en.csv',
#  '1.CourseOverview,IntervalScheduling-2P-yW7LQr08.en.csv',
#  'LinkedList-ImplementationinC_C++-vcQIFT79_50.en.csv',
#  'Crossproductintroduction_Vectorsandspaces_LinearAlgebra_KhanAcademy-pJzmiywagfY.en.csv',
#  'Lec10_MIT18.086MathematicalMethodsforEngineersII-NpTzMWTYbM8.en.csv',
#  'RooksonaChessboard-Na4R11fWVJg.en.csv',
#  '13.Regression-yP1S37BiEsQ.en.csv',
#  '2.ThermodynamicsPart2-EQB2Pw0lWRU.en.csv',
#  'Matrixproductassociativity_Matrixtransformations_LinearAlgebra_KhanAcademy-Hhc96U_HvQE.en.csv',
#  '22.HistoryofMemoryModels-3e1ZF1L1VhY.en.csv',
#  'LaplaceaslinearoperatorandLaplaceofderivatives_Laplacetransform_KhanAcademy-E2VxbufzuWQ.en.csv',
#  'Lecture32-MarkovChainsContinued_Statistics110-aBGOyZv2pZE.en.csv',
#  'Lecture4-ConditionalProbability_Statistics110-P7NE4WF8j-Q.en.csv',
#  '3.ParametricInference-TSkDZbGS94k.en.csv',
#  'TheSumofDiscreteandContinuousRandomVariables-8ueUXUTRlSQ.en.csv',
#  'Lec4_MIT6.042JMathematicsforComputerScience,Fall2010-NuY7szYSXSw.en.csv',
#  'R21.DynamicProgramming-KnapsackProblem-wFP5VHGHFdk.en.csv',
#  'Lec15_MIT18.086MathematicalMethodsforEngineersII-LtNVodIs1dI.en.csv',
#  "10.ContinuousBayes'Rule;DerivedDistributions-H_k1w3cfny8.en.csv",
#  'Lecture5-BackpropagationandProjectAdvice-isPiE-DBagM.en.csv',
#  '22.ProbabilisticInferenceII-EC6bf8JCpDQ.en.csv',
#  'L02.7TotalProbabilityTheorem-8odFouBR2wE.en.csv',
#  'Lec12_MIT18.086MathematicalMethodsforEngineersII-r1-r1t5i58g.en.csv',
#  'Lec31_MIT18.02MultivariableCalculus,Fall2007-tzoYhe3H5dM.en.csv',
#  '7.Finite-stateMarkovChains;TheMatrixApproach-0aqgeLTNfQ0.en.csv',
#  'FunctionCalls-4gPwo38MNss.en.csv',
#  'Week8,continued-ihmHDZKOkA8.en.csv',
#  '4.ThermodynamicsPart4-__tGxUu5BTc.en.csv',
#  'Matrixconditionforone-to-onetrans_Matrixtransformations_LinearAlgebra_KhanAcademy-M3FuL9qKTBs.en.csv',
#  'Lec5_MIT18.02MultivariableCalculus,Fall2007-57jzPlxf4fk.en.csv']

# %%
#look at a file example
csv_files[0]
# Out:
# 'VisualizingacolumnspaceasaplaneinR3_Vectorsandspaces_LinearAlgebra_KhanAcademy-EGNlXtjYABw.en.csv'

# %%
#remove the spaces from the names
path = '/math2clean/assets/'
for filename in csv_files:
    os.rename(os.path.join(path, filename), os.path.join(path, filename.replace(' ', '')))

# %%
clean_csv = sorted([os.fsdecode(file) for file in os.listdir(os.getcwd()+'/math2clean/assets')])
'''clean_csv'''
# Out:
# 'clean_csv'

# %%
#extrat the text and videoid
vidText = []
csv_vidid = []
path = 'math2clean/assets/'
for file in clean_csv:
    
    df = pd.read_csv(path+file)
    text = " ".join(df.text)
    vidText.append(text)
    csv_vidid.append(file[-18:-7])

# %%
#set up a data frame with the available caption information
lectures_df = pd.DataFrame()
lectures_df['lecture_title'] = clean_csv
lectures_df['lecture_text'] = vidText
lectures_df['vid_id'] = csv_vidid

# %% [markdown]
# ## Adding infomation from youtube api and captions scraped together
#     -Because we had a list of 913 videos and only 675 had downloadable captions, when we add the information together
#     we will need to discard some of the videos in the api videoId list.
#     -To do this we will join the two DFs using the video ID as the index.

# %%
lectures_df.shape
# Out:
# (868, 3)

# %%
lectures_df.head(1)
# Out:
#                                        lecture_title  \
# 0  'Shifting'transformbymultiplyingfunctionbyexpo...
#
#                                         lecture_text       vid_id
# 0  Now I think is a good time\nto add some notati...  _X_QwpXsdOs

# %%
video_df.head(1)
# Out:
#                     title                                        description  \
# 0  L01.1 Lecture Overview  MIT RES.6-012 Introduction to Probability, Spr...
#
#             channelid     videoids                         playlist_id
# 0  MIT OpenCourseWare  1uW3qMFA9Ho  PLUl4u3cNGP60hI9ATjSFgLZpbNJ7myAg6

# %%
base_df = lectures_df.set_index('vid_id').join(video_df.set_index('videoids')).reset_index()

# %%
base_df.shape
# Out:
# (892, 7)

# %%
base_df.head()
# Out:
#          index                                      lecture_title  \
# 0  --lPz7VFnKI  Lec39_MIT18.01SingleVariableCalculus,Fall2007-...
# 1  -630YTQEuCI  S01.0MathematicalBackgroundOverview--630YTQEuC...
# 2  -DP1i2ZU9gk     8.ObjectOrientedProgramming--DP1i2ZU9gk.en.csv
# 3  -DwGrJ8JxDc  Recitation9b-DNASequenceMatching--DwGrJ8JxDc.e...
# 4  -FElVPKykgw                 R10.Quiz1Review--FElVPKykgw.en.csv
#
#                                         lecture_text  \
# 0  The following content is\nprovided under a Cre...
# 1  In this sequence of segments,\nwe review some ...
# 2  The following content is\nprovided under a Cre...
# 3  The following\ncontent is provided under a Cre...
# 4  The following\ncontent is provided under a Cre...
#
#                                                title  \
# 0  Lec 39 | MIT 18.01 Single Variable Calculus, F...
# 1             S01.0 Mathematical Background Overview
# 2                     8. Object Oriented Programming
# 3               Recitation 9b: DNA Sequence Matching
# 4                                 R10. Quiz 1 Review
#
#                                          description           channelid  \
# 0  Lecture 39: Final review\nInstructor: David Je...  MIT OpenCourseWare
# 1  MIT RES.6-012 Introduction to Probability, Spr...  MIT OpenCourseWare
# 2  MIT 6.0001 Introduction to Computer Science an...  MIT OpenCourseWare
# 3  MIT 6.006 Introduction to Algorithms, Fall 201...  MIT OpenCourseWare
# 4  MIT 6.006 Introduction to Algorithms, Fall 201...  MIT OpenCourseWare
#
#                           playlist_id
# 0                  PL590CCC2BC5AF3BC1
# 1  PLUl4u3cNGP60hI9ATjSFgLZpbNJ7myAg6
# 2  PLUl4u3cNGP63WbdFxL8giv4yhgdMGaZNA
# 3  PLUl4u3cNGP61Oq3tWYp6V_F-5jb5L2iHb
# 4  PLUl4u3cNGP61Oq3tWYp6V_F-5jb5L2iHb

# %%
#drop duplicates
base_df = base_df.drop_duplicates(subset=['index'])

# %%
base_df.shape
# Out:
# (868, 7)

# %%
base_df.head(1)
# Out:
#          index                                      lecture_title  \
# 0  --lPz7VFnKI  Lec39_MIT18.01SingleVariableCalculus,Fall2007-...
#
#                                         lecture_text  \
# 0  The following content is\nprovided under a Cre...
#
#                                                title  \
# 0  Lec 39 | MIT 18.01 Single Variable Calculus, F...
#
#                                          description           channelid  \
# 0  Lecture 39: Final review\nInstructor: David Je...  MIT OpenCourseWare
#
#           playlist_id
# 0  PL590CCC2BC5AF3BC1

# %%
base_df['vidid'] = base_df['index']
base_df = base_df.drop(['index'],axis=1)

# %%
base_df.head()
# Out:
#                                        lecture_title  \
# 0  Lec39_MIT18.01SingleVariableCalculus,Fall2007-...
# 1  S01.0MathematicalBackgroundOverview--630YTQEuC...
# 2     8.ObjectOrientedProgramming--DP1i2ZU9gk.en.csv
# 3  Recitation9b-DNASequenceMatching--DwGrJ8JxDc.e...
# 4                 R10.Quiz1Review--FElVPKykgw.en.csv
#
#                                         lecture_text  \
# 0  The following content is\nprovided under a Cre...
# 1  In this sequence of segments,\nwe review some ...
# 2  The following content is\nprovided under a Cre...
# 3  The following\ncontent is provided under a Cre...
# 4  The following\ncontent is provided under a Cre...
#
#                                                title  \
# 0  Lec 39 | MIT 18.01 Single Variable Calculus, F...
# 1             S01.0 Mathematical Background Overview
# 2                     8. Object Oriented Programming
# 3               Recitation 9b: DNA Sequence Matching
# 4                                 R10. Quiz 1 Review
#
#                                          description           channelid  \
# 0  Lecture 39: Final review\nInstructor: David Je...  MIT OpenCourseWare
# 1  MIT RES.6-012 Introduction to Probability, Spr...  MIT OpenCourseWare
# 2  MIT 6.0001 Introduction to Computer Science an...  MIT OpenCourseWare
# 3  MIT 6.006 Introduction to Algorithms, Fall 201...  MIT OpenCourseWare
# 4  MIT 6.006 Introduction to Algorithms, Fall 201...  MIT OpenCourseWare
#
#                           playlist_id        vidid
# 0                  PL590CCC2BC5AF3BC1  --lPz7VFnKI
# 1  PLUl4u3cNGP60hI9ATjSFgLZpbNJ7myAg6  -630YTQEuCI
# 2  PLUl4u3cNGP63WbdFxL8giv4yhgdMGaZNA  -DP1i2ZU9gk
# 3  PLUl4u3cNGP61Oq3tWYp6V_F-5jb5L2iHb  -DwGrJ8JxDc
# 4  PLUl4u3cNGP61Oq3tWYp6V_F-5jb5L2iHb  -FElVPKykgw

# %%
#save the csv
base_df.to_csv('all_lectures.csv', index=False)
